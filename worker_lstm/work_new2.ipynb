# %%
import mmap
import time
from time import strftime, localtime
import glob
import os
import json
from collections import deque

import import_ipynb
import torch
import torch.nn.functional as F
from torch.distributions import Categorical
from torch_geometric.data import Data
from torch.utils.tensorboard import SummaryWriter
import numpy as np
import sys 
import win32pipe, win32file, pywintypes

from actor import actor_network

torch.set_printoptions(threshold=10_000)
np.set_printoptions(threshold=sys.maxsize)



BUFFER_SIZE = 200000

# %% [markdown]
# # 통신 관련 함수

# %%
def sendOmnetMessage(msg):
    win32file.WriteFile(pipe, msg.encode('utf-8'))
    
def getOmnetMessage():
    response_byte = win32file.ReadFile(pipe, BUFFER_SIZE)
    response_str = response_byte[1].decode('utf-8')
    return response_str

def closePipe():
    win32file.CloseHandle(pipe)

# %% [markdown]
# # 실험 정보 관련 함수

# %%
def recordExpInfo(config):

    networkInfo = config["network_info"]

    modelNum = int(networkInfo['modelNum'])
    availableJobNum = int(networkInfo['availableJobNum'])
    nodeNum = int(networkInfo['nodeNum'])
    jobWaitingLength = int(networkInfo['jobWaitingQueueLength'])
    adjacency = eval(networkInfo['adjacencyList'])
    episode_length = int(networkInfo['episode_length'])
    node_capacity = networkInfo['node_capacity']
    job_generate_rate = networkInfo['job_generate_rate']

    node_feature_num = 2 * (modelNum * availableJobNum)
    queue_feature_num = (nodeNum + modelNum) * jobWaitingLength
    hidden_feature_num = 10*(node_feature_num + queue_feature_num)
    reward_weight = 1/modelNum
    entropy_weight = config["entropy_weight"]
    
    info = f"""
    노드 개수 : {nodeNum}
    네트워크 최대 job 개수 : {availableJobNum}
    job 대기 가능 개수 : {jobWaitingLength}
    최대 subtask 개수 : {modelNum}
    인접 리스트 : {adjacency}
    node_feature_num : {node_feature_num}
    queue_feature_num : {queue_feature_num}
    episode_length : {episode_length}
    node_capacity : {node_capacity}
    entropy_weight : {entropy_weight}
    reward_weight : {reward_weight}
    job_generate_rate : {job_generate_rate}
    """
    print(info)

    with open(f'{config["path_name"]}/info.txt', 'w') as f:
        f.write(f'{info}')

# %%
def main(config):
    global adjacency, writer

    recordExpInfo(config)
    
    model = actor_network(config)
    # model.load_state_dict(torch.load("C:/Users/user/Desktop/suhwan/connection_test/python_agent/experiment/subtask_num_test_same_env/history23/model_24300.pth"))
    reward_history = []
    v_history = []

    adjacency = torch.tensor(adjacency, dtype=torch.long)

    step = 1
    episode = 1

    max_reward = 0

    average_reward = 0
    average_reward_num = 0

    temp_history = deque([])

    isStop = False
    node_selected_num = [0 for i in range(config["node_num"])]
    void_selected_num = 0

    pre_state_1 = {}
    pre_state_2 = {}

    void_mask = [0] * config["node_num"] + [1]
    unvoid_mask = [1] * config["node_num"] + [0]

    episode_total_reward = 0
    hidden = (torch.zeros(1, 1, config["lstm_hidden_num"]), torch.zeros(1, 1, config["lstm_hidden_num"]))
    
    while True:
        # time.sleep(config["cpu_load_balance_time"])
        
        model = model.to('cpu')
        msg = getOmnetMessage()
        
        if msg == "action": # omnet의 메세지, state 받으면 됨
            sendOmnetMessage("ok")
            state_1 = getOmnetMessage()
            state_2 = getOmnetMessage()

            if len(state_1) == 0:
                state_1 = state_2
            

            if len(pre_state_1) == 0: # action 시작
                state_1 = json.loads(state_1) # state 받았으므로 action 하면됨.
                state_2 = json.loads(state_2) # state 받았으므로 action 하면됨.
                
            else:
                state_1 = json.loads(state_1)
                pre_state_1['jobWaiting'] = state_1['jobWaiting']
                pre_state_1['sojournTime'] = state_1['sojournTime']
                state_1 = pre_state_1

                state_2 = json.loads(state_2)
                pre_state_2['jobWaiting'] = state_2['jobWaiting']
                pre_state_2['sojournTime'] = state_2['sojournTime']
                state_2 = pre_state_2
            
            sendOmnetMessage("ok") # 답장

            
            node_waiting_state_1 = torch.tensor(eval(str(state_1['nodeState'])), dtype=torch.float)
            node_processing_state_1 = torch.tensor(eval(state_1['nodeProcessing']), dtype=torch.float)
            link_state_1 = torch.tensor(eval(state_1['linkWaiting']), dtype=torch.float)
            job_waiting_state_1 = torch.tensor(eval(state_1['jobWaiting']), dtype=torch.float)
            activated_job_list_1 = eval(state_1['activatedJobList'])
            isAction_1 = int(state_1['isAction'])
            reward_1 = float(state_1['reward'])
            averageLatency_1 = float(state_1['averageLatency'])
            completeJobNum_1 = int(state_1['completeJobNum'])
            sojournTime_1 = float(state_1['sojournTime'])

            node_waiting_state_2 = torch.tensor(eval(str(state_2['nodeState'])), dtype=torch.float)
            node_processing_state_2 = torch.tensor(eval(state_2['nodeProcessing']), dtype=torch.float)
            link_state_2 = torch.tensor(eval(state_2['linkWaiting']), dtype=torch.float)
            job_waiting_state_2 = torch.tensor(eval(state_2['jobWaiting']), dtype=torch.float)
            activated_job_list_2 = eval(state_2['activatedJobList'])
            isAction_2 = int(state_2['isAction'])
            reward_2 = float(state_2['reward'])
            averageLatency_2 = float(state_2['averageLatency'])
            completeJobNum_2 = int(state_2['completeJobNum'])
            sojournTime_2 = float(state_2['sojournTime'])

            # node_waiting_state_2 = torch.tensor(eval(str(state_1['nodeState'])), dtype=torch.float)
            # node_processing_state_2 = torch.tensor(eval(state_1['nodeProcessing']), dtype=torch.float)
            # link_state_2 = torch.tensor(eval(state_1['linkWaiting']), dtype=torch.float)
            # job_waiting_state_2 = torch.tensor(eval(state_1['jobWaiting']), dtype=torch.float)
            # activated_job_list_2 = eval(state_1['activatedJobList'])
            # isAction_2 = int(state_1['isAction'])
            # reward_2 = float(state_1['reward'])
            # averageLatency_2 = float(state_1['averageLatency'])
            # completeJobNum_2 = int(state_1['completeJobNum'])
            # sojournTime_2 = float(state_1['sojournTime'])

            writer.add_scalar("completeJobNum/train", completeJobNum_2 ,step)

            #print(node_waiting_state_2)
            #print(node_processing_state_2)
            

            # # 이 timestep에서 발생한 모든 샘플에 똑같은 보상 적용.
            # if averageLatency_2 == -1:
            #     reward_2 = 0
            # else:
            #     reward_2 = completeJobNum_2
            
            writer.add_scalar("Reward/train", reward_2, step)

            episode_total_reward += reward_2
                
            first_sample = True
            if config["is_train"] and len(pre_state_1) == 0:
                while temp_history:
                    history = temp_history.popleft()
                    history[3] = reward_2
                    history[4] = network_state
                    history[5] = job_waiting_state
                    model.history.append(history)
                    model.put_data(history)

            

            temp_history = deque([])

            job_index = int(state_2['jobIndex'])

            #print('sojourn time :', sojournTime)


            # node_state_1 = np.concatenate((node_waiting_state_1,node_processing_state_1) ,axis = 1)
            #node_state_1 = torch.concat([node_waiting_state_1, node_processing_state_1], dim=1)
            node_state_1 = node_waiting_state_1
            # node_state_2 = np.concatenate((node_waiting_state_2,node_processing_state_2) ,axis = 1)
            #node_state_2 = torch.concat([node_waiting_state_2, node_processing_state_2], dim=1)
            node_state_2 = node_waiting_state_2

            #print(reward)

            # link_state_1 = torch.tensor(link_state_1, dtype=torch.float)
            # link_state_2 = torch.tensor(link_state_2, dtype=torch.float)

            job_waiting_num = 0
            job_waiting_queue = deque()
            for job in job_waiting_state_2:
                if any(job): # 하나라도 0이 아닌 것 이 있으면 job이 있는것임.
                    job_waiting_num += 1
                    job_waiting_queue.append(job)
            
            job_waiting_state_1 = job_waiting_state_1.view(1, -1)
            job_waiting_state_2 = job_waiting_state_2.view(1, -1)
            # print(job_waiting_state)

            network_state_1 = Data(x=node_state_1, edge_attr=link_state_1, edge_index=adjacency)
            network_state_2 = Data(x=node_state_2, edge_attr=link_state_2, edge_index=adjacency)

            network_state = [network_state_1, network_state_2]
            job_waiting_state = [job_waiting_state_1, job_waiting_state_2]

            pre_state_1 = state_1
            pre_state_2 = state_2
            
            if average_reward_num == 0:
                average_reward = reward_2
                average_reward_num = 1
            else:
                average_reward = average_reward + (reward_2 - average_reward)/(average_reward_num + 1)
                average_reward_num += 1
                
            if step > 1:
                for i in range(config["node_num"]):
                    node_tag = "node/" + str(i) + "/train"
                    writer.add_scalar(node_tag, node_selected_num[i], step)

                writer.add_scalar("node/void/train", void_selected_num, step)
                    
                node_selected_num = [0 for i in range(config["node_num"])] # node selected num 초기화
                void_selected_num = 0

                if reward_2 != 0:
                    with torch.no_grad():
                        state = model.gnn([network_state, job_waiting_state])
                        writer.add_scalar("Value/train", torch.mean(model.v(state)), step)
                

                writer.flush()

            
            
            # print(job_waiting_queue)
            if job_waiting_num == 0:
                isAction_2 = False
                

            if isAction_2:
                if step % config["T_horizon"] == 0:
                    if config["is_train"]:
                        if episode % 100 == 0:
                            tm = localtime(time.time())
                            time_string = strftime('%Y-%m-%d %I:%M:%S %p', tm)
                            print(f"[{time_string}] training....")
                        model.train_net()
                        if episode % 100 == 0:
                            tm = localtime(time.time())
                            time_string = strftime('%Y-%m-%d %I:%M:%S %p', tm)
                            print(f"[{time_string}] training complete")

                        model = model.cpu()


                job_idx = job_index
                job = job_waiting_queue.popleft()
                src = -1
                dst = 1
                for i in range(config["node_num"]):
                    if job[i] == -1:
                        src = i
                    if job[i] == 1:
                        dst = i

                if src == -1:
                    src = dst
                    
                #print(f"src : {src}, dst : {dst}")
                #print(job)
                subtasks = job[config["node_num"]:]
                offloading_vector = []
                temp_data = []
                scheduling_start = False
                # print(subtasks)
                step += 1

                with torch.no_grad():
                    feature = model.gnn([network_state, job_waiting_state])
                    new_feature = feature.repeat(config["model_num"], 1).unsqueeze(0)
                    first_prob, entropy, output, hidden = model.pi([new_feature, hidden])

                writer.add_scalar("Entropy/train", torch.mean(entropy).item(), step)
                #print(f'prob : {prob}')

                # isVoid = F.sigmoid(dists[modelNum].sample())

                m = Categorical(first_prob[0][0]) # 첫 번째 batch의 첫 번째 node+void개의 확률들
                nodes = m.sample()

                node = nodes.item()

                #print(f'node : {node}')
                
                # void action 실험용
                # node = nodeNum 
                
                
                # void action 뽑으면 void만 업데이트
                if node == config["node_num"] and not scheduling_start: 
                    action_mask = void_mask

                    temp_history.append([
                        [network_state[0], network_state[1]], 
                        [job_waiting_state[0], job_waiting_state[1]], 
                        node, 0, 
                        [network_state[0], network_state[1]], 
                        [job_waiting_state[0], job_waiting_state[1]],
                        1, 
                        0, action_mask, 0]
                    )

                    sendOmnetMessage("void")

                    #print("action finish.")
                    
                    if getOmnetMessage() == "ok":
                        void_selected_num += 1

                else:
                    scheduling_start = True

                if scheduling_start:

                    with torch.no_grad():
                        feature = model.gnn([network_state, job_waiting_state])
                        # print(feature)
                        new_feature = feature.repeat(config["model_num"], 1).unsqueeze(0)
                        prob, entropy, output, hidden = model.pi([new_feature, hidden])

                    output = output[:, :, 0:-1].squeeze(0)


                    prob = F.softmax(output, dim=1)
                    prob = torch.concat([prob, torch.zeros(config["model_num"], 1)], dim=1)


                    m = Categorical(prob)
                    nodes = m.sample()
                    action_mask = unvoid_mask

                    for index in range(config["model_num"]):

                        node = nodes[index].item()
                        #node = torch.argmin(node_waiting_state_2[:,0]).item()

                        temp_history.append([
                        [network_state[0], network_state[1]], 
                        [job_waiting_state[0], job_waiting_state[1]], 
                        node, -1, 
                        [-1, -1], 
                        [-1, -1],
                        prob[index][node].item(),
                        0, action_mask, index]
                        )

                        offloading_vector.append(node)
                        node_selected_num[node] += 1
                    
                if len(offloading_vector) != 0: # for문을 다 돌면 -> void action 안뽑으면
                    # print(offloading_vector)
                    msg = str(offloading_vector)
                    sendOmnetMessage(msg)
                    
                    #print("action finish.")
                    if(getOmnetMessage() == "ok"):
                        pass

        elif msg == "stop":
            
            sendOmnetMessage("ok")
            pre_state_1 = {}
            pre_state_2 = {}
            
        elif msg == "episode_finish":
            sendOmnetMessage("ok")

            # print(len(model.history))

            episodic_reward = getOmnetMessage()
            episodic_reward = json.loads(episodic_reward)
            
            finish_num = float(episodic_reward['reward'])
            complete_num = int(episodic_reward['completNum'])
            average_latency = float(episodic_reward['averageLatency'])
            jitter = episodic_reward['jitter']
            jitterMake = episodic_reward['jitterMake']
            #print(list(map(float, jitter.strip().split(" "))))
            #print(list(map(float, jitterMake.strip().split(" "))))

            normalized_finish_num = model.return_normalize_reward(finish_num)
            
            writer.add_scalar("EpisodicReward/train", finish_num, episode)
            writer.add_scalar("NormalizedEpisodicReward/train", normalized_finish_num, episode)
            writer.add_scalar("CompleteNum/train", complete_num, episode)
            writer.add_scalar("averageLatency/train", average_latency ,episode)

            

            episode_total_reward += complete_num

            writer.add_scalar("episode_total_reward/train", episode_total_reward, episode)

            episode_total_reward = 0
            hidden = (torch.zeros(1, 1, config["lstm_hidden_num"]), torch.zeros(1, 1, config["lstm_hidden_num"]))

            episode += 1
            sendOmnetMessage("ok")

            if finish_num > max_reward:
                modelPathName = config["path_name"] + "/max_model.pth"
                torch.save(model.state_dict(), modelPathName)
                max_reward = finish_num

            writer.add_scalar("AverageReward/train", average_reward, step)
            average_reward = 0
            average_reward_num = 0

            if config["is_train"]:
                
                if episode % 100 == 0:
                    tm = localtime(time.time())
                    time_string = strftime('%Y-%m-%d %I:%M:%S %p', tm)
                    print(f"[{time_string}] training....")
                model.train_net()
                if episode % 100 == 0:
                    tm = localtime(time.time())
                    time_string = strftime('%Y-%m-%d %I:%M:%S %p', tm)
                    print(f"[{time_string}] training complete")

                if episode % 100 == 0:
                    tm = localtime(time.time())
                    time_string = strftime('%Y-%m-%d %I:%M:%S %p', tm)
                    print(f"[{time_string}] training replay buffer....")
                model.train_net_history()
                if episode % 100 == 0:
                    tm = localtime(time.time())
                    time_string = strftime('%Y-%m-%d %I:%M:%S %p', tm)
                    print(f"[{time_string}] training complete")

                model.clear_data()

                if episode % 100 == 0:
                    modelPathName = config["path_name"] + f"/model_{episode}.pth"
                    torch.save(model.state_dict(), modelPathName)

                    time.sleep(10)
                
                modelPathName = config["path_name"] + "/model.pth"
                torch.save(model.state_dict(), modelPathName)

# %% [markdown]
# # 통신 관련 초기화

# %%
PIPE_NAME = "\\\\.\\pipe\\worker_right_2"
BUFFER_SIZE = 200000

try:
    pipe = win32pipe.CreateNamedPipe(
        PIPE_NAME,
        win32pipe.PIPE_ACCESS_DUPLEX,
        win32pipe.PIPE_TYPE_MESSAGE | win32pipe.PIPE_READMODE_MESSAGE | win32pipe.PIPE_WAIT,
        1,
        BUFFER_SIZE,
        BUFFER_SIZE,
        0,
        None
    )    
except:
    pass

win32pipe.ConnectNamedPipe(pipe, None)

# %%
initial_message = getOmnetMessage()
networkInfo = json.loads(initial_message)

modelNum = int(networkInfo['modelNum'])
availableJobNum = int(networkInfo['availableJobNum'])
nodeNum = int(networkInfo['nodeNum'])
jobWaitingLength = int(networkInfo['jobWaitingQueueLength'])
adjacency = eval(networkInfo['adjacencyList'])
episode_length = int(networkInfo['episode_length'])
node_capacity = networkInfo['node_capacity']
job_generate_rate = networkInfo['job_generate_rate']

node_feature_num = 2 * (modelNum * availableJobNum)
queue_feature_num = (nodeNum + modelNum) * jobWaitingLength
hidden_feature_num = 10*(node_feature_num + queue_feature_num)
reward_weight = 1/modelNum

# %%
os.chdir("C:/Users/user/Desktop/suhwan/connection_test/python_agent/experiment/subtask_num_test_same_env")
folderList = glob.glob("history*")

pathName = "history" + str(len(folderList))

print(pathName)

os.mkdir(pathName)

writer = SummaryWriter(pathName)

# %%
if __name__ == '__main__':
    sendOmnetMessage("init") # 입력 끝나면 omnet에 전송
    print("네트워크 초기화 완료")

    config = {
        "learning_rate"         : 0.0001,
        "gamma"                 : 0.99,
        "entropy_weight"        : 0.03,
        "lambda"                : 0.99,
        "eps_clip"              : 0.1,
        "batch_size"            : 256,
        "loss_coef"             : 0.5,
        "job_generate_rate"     : 0.003,
        "is_train"              : True,
        "replay_buffer_size"    : 1000,
        "history_learning_time" : 0,
        "current_learning_time" : 2,
        "node_feature_num"      : 4,
        "queue_feature_num"     : (nodeNum + modelNum) * jobWaitingLength,
        "hidden_feature_num"    : 40,
        "reward_weight"         : 1.0/1,
        "node_num"              : nodeNum,
        "model_num"             : modelNum,
        "lstm_hidden_num"       : 30,
        "cpu_load_balance_time" : 0.1,
        "network_info"          : networkInfo,
        "path_name"             : pathName,
        "T_horizon"             : 20,
    }


    main(config)
# Out:
# [2023-03-02 11:22:56 AM] training....
# [2023-03-02 11:22:56 AM] training complete
# [2023-03-02 11:22:56 AM] training replay buffer....
# [2023-03-02 11:22:56 AM] training complete
# [2023-03-02 11:23:07 AM] training....
# [2023-03-02 11:23:07 AM] training complete
# [2023-03-02 11:23:08 AM] training....
# [2023-03-02 11:23:09 AM] training complete
# [2023-03-02 11:23:09 AM] training....
# [2023-03-02 11:23:10 AM] training complete
# [2023-03-02 11:23:11 AM] training....
# [2023-03-02 11:23:11 AM] training complete
# [2023-03-02 11:23:12 AM] training....
# [2023-03-02 11:23:12 AM] training complete
# [2023-03-02 11:23:13 AM] training....
# [2023-03-02 11:23:14 AM] training complete
# [2023-03-02 11:32:01 AM] training....
# [2023-03-02 11:32:02 AM] training complete
# [2023-03-02 11:32:02 AM] training replay buffer....
# [2023-03-02 11:32:02 AM] training complete
# [2023-03-02 11:32:12 AM] training....
# [2023-03-02 11:32:12 AM] training complete
# [2023-03-02 11:32:13 AM] training....
# [2023-03-02 11:32:13 AM] training complete
# [2023-03-02 11:32:14 AM] training....
# [2023-03-02 11:32:14 AM] training complete
# [2023-03-02 11:32:15 AM] training....
# [2023-03-02 11:32:15 AM] training complete
# [2023-03-02 11:40:42 AM] training....
# [2023-03-02 11:40:43 AM] training complete
# [2023-03-02 11:40:43 AM] training replay buffer....
# [2023-03-02 11:40:43 AM] training complete
# [2023-03-02 11:40:53 AM] training....
# [2023-03-02 11:40:54 AM] training complete
# [2023-03-02 11:40:54 AM] training....
# [2023-03-02 11:40:55 AM] training complete
# [2023-03-02 11:40:56 AM] training....
# [2023-03-02 11:40:56 AM] training complete
# [2023-03-02 11:51:25 AM] training....
# [2023-03-02 11:51:25 AM] training complete
# [2023-03-02 11:51:25 AM] training replay buffer....
# [2023-03-02 11:51:25 AM] training complete
# [2023-03-02 11:51:35 AM] training....
# [2023-03-02 11:51:36 AM] training complete
# [2023-03-02 11:51:36 AM] training....
# [2023-03-02 11:51:37 AM] training complete
# [2023-03-02 11:51:38 AM] training....
# [2023-03-02 11:51:38 AM] training complete
# [2023-03-02 11:51:39 AM] training....
# [2023-03-02 11:51:39 AM] training complete
# [2023-03-02 11:51:40 AM] training....
# [2023-03-02 11:51:41 AM] training complete
# [2023-03-02 12:02:10 PM] training....
# [2023-03-02 12:02:10 PM] training complete
# [2023-03-02 12:02:10 PM] training replay buffer....
# [2023-03-02 12:02:10 PM] training complete
# [2023-03-02 12:02:20 PM] training....
# [2023-03-02 12:02:21 PM] training complete
# [2023-03-02 12:02:21 PM] training....
# [2023-03-02 12:02:22 PM] training complete
# [2023-03-02 12:02:23 PM] training....
# [2023-03-02 12:02:23 PM] training complete
# [2023-03-02 12:02:24 PM] training....
# [2023-03-02 12:02:24 PM] training complete
# [2023-03-02 12:02:25 PM] training....
# [2023-03-02 12:02:26 PM] training complete
# [2023-03-02 12:12:30 PM] training....
# [2023-03-02 12:12:31 PM] training complete
# [2023-03-02 12:12:31 PM] training replay buffer....
# [2023-03-02 12:12:31 PM] training complete
# [2023-03-02 12:12:41 PM] training....
# [2023-03-02 12:12:41 PM] training complete
# [2023-03-02 12:12:42 PM] training....
# [2023-03-02 12:12:43 PM] training complete
# [2023-03-02 12:12:44 PM] training....
# [2023-03-02 12:12:44 PM] training complete
# [2023-03-02 12:12:45 PM] training....
# [2023-03-02 12:12:45 PM] training complete
# [2023-03-02 12:12:46 PM] training....
# [2023-03-02 12:12:46 PM] training complete
# [2023-03-02 12:12:47 PM] training....
# [2023-03-02 12:12:48 PM] training complete
# [2023-03-02 12:21:23 PM] training....
# [2023-03-02 12:21:23 PM] training complete
# [2023-03-02 12:21:23 PM] training replay buffer....
# [2023-03-02 12:21:23 PM] training complete
# [2023-03-02 12:21:34 PM] training....
# [2023-03-02 12:21:34 PM] training complete
# [2023-03-02 12:21:35 PM] training....
# [2023-03-02 12:21:35 PM] training complete
# [2023-03-02 12:21:36 PM] training....
# [2023-03-02 12:21:36 PM] training complete
# [2023-03-02 12:29:33 PM] training....
# [2023-03-02 12:29:33 PM] training complete
# [2023-03-02 12:29:33 PM] training replay buffer....
# [2023-03-02 12:29:33 PM] training complete
# [2023-03-02 12:29:43 PM] training....
# [2023-03-02 12:29:44 PM] training complete
# [2023-03-02 12:29:45 PM] training....
# [2023-03-02 12:29:45 PM] training complete
# [2023-03-02 12:29:46 PM] training....
# [2023-03-02 12:29:46 PM] training complete
# [2023-03-02 12:29:47 PM] training....
# [2023-03-02 12:29:47 PM] training complete
# [2023-03-02 12:38:00 PM] training....
# [2023-03-02 12:38:00 PM] training complete
# [2023-03-02 12:38:00 PM] training replay buffer....
# [2023-03-02 12:38:00 PM] training complete
# [2023-03-02 12:38:11 PM] training....
# [2023-03-02 12:38:11 PM] training complete
# [2023-03-02 12:38:12 PM] training....
# [2023-03-02 12:38:12 PM] training complete
# [2023-03-02 12:38:13 PM] training....
# [2023-03-02 12:38:14 PM] training complete
# [2023-03-02 12:38:14 PM] training....
# [2023-03-02 12:38:15 PM] training complete
# [2023-03-02 12:46:42 PM] training....
# [2023-03-02 12:46:43 PM] training complete
# [2023-03-02 12:46:43 PM] training replay buffer....
# [2023-03-02 12:46:43 PM] training complete
# [2023-03-02 12:46:53 PM] training....
# [2023-03-02 12:46:54 PM] training complete
# [2023-03-02 12:46:54 PM] training....
# [2023-03-02 12:46:55 PM] training complete
# [2023-03-02 12:46:56 PM] training....
# [2023-03-02 12:46:56 PM] training complete
# [2023-03-02 12:46:57 PM] training....
# [2023-03-02 12:46:57 PM] training complete
# [2023-03-02 12:56:04 PM] training....
# [2023-03-02 12:56:04 PM] training complete
# [2023-03-02 12:56:04 PM] training replay buffer....
# [2023-03-02 12:56:04 PM] training complete
# [2023-03-02 12:56:15 PM] training....
# [2023-03-02 12:56:15 PM] training complete
# [2023-03-02 12:56:16 PM] training....
# [2023-03-02 12:56:16 PM] training complete
# [2023-03-02 12:56:17 PM] training....
# [2023-03-02 12:56:18 PM] training complete
# [2023-03-02 01:05:59 PM] training....
# [2023-03-02 01:05:59 PM] training complete
# [2023-03-02 01:05:59 PM] training replay buffer....
# [2023-03-02 01:05:59 PM] training complete
# [2023-03-02 01:06:09 PM] training....
# [2023-03-02 01:06:10 PM] training complete
# [2023-03-02 01:06:11 PM] training....
# [2023-03-02 01:06:11 PM] training complete
# [2023-03-02 01:06:12 PM] training....
# [2023-03-02 01:06:12 PM] training complete
# [2023-03-02 01:06:13 PM] training....
# [2023-03-02 01:06:14 PM] training complete
# [2023-03-02 01:06:15 PM] training....
# [2023-03-02 01:06:15 PM] training complete
# [2023-03-02 01:15:00 PM] training....
# [2023-03-02 01:15:00 PM] training complete
# [2023-03-02 01:15:00 PM] training replay buffer....
# [2023-03-02 01:15:00 PM] training complete
# [2023-03-02 01:15:11 PM] training....
# [2023-03-02 01:15:11 PM] training complete
# [2023-03-02 01:15:12 PM] training....
# [2023-03-02 01:15:12 PM] training complete
# [2023-03-02 01:15:13 PM] training....
# [2023-03-02 01:15:14 PM] training complete
# [2023-03-02 01:15:15 PM] training....
# [2023-03-02 01:15:15 PM] training complete
# [2023-03-02 01:23:41 PM] training....
# [2023-03-02 01:23:41 PM] training complete
# [2023-03-02 01:23:41 PM] training replay buffer....
# [2023-03-02 01:23:41 PM] training complete
# [2023-03-02 01:23:52 PM] training....
# [2023-03-02 01:23:52 PM] training complete
# [2023-03-02 01:23:53 PM] training....
# [2023-03-02 01:23:53 PM] training complete
# [2023-03-02 01:23:54 PM] training....
# [2023-03-02 01:23:54 PM] training complete
# [2023-03-02 01:23:55 PM] training....
# [2023-03-02 01:23:56 PM] training complete
# [2023-03-02 01:32:36 PM] training....
# [2023-03-02 01:32:36 PM] training complete
# [2023-03-02 01:32:36 PM] training replay buffer....
# [2023-03-02 01:32:36 PM] training complete
# [2023-03-02 01:32:47 PM] training....
# [2023-03-02 01:32:47 PM] training complete
# [2023-03-02 01:32:48 PM] training....
# [2023-03-02 01:32:48 PM] training complete
# [2023-03-02 01:32:49 PM] training....
# [2023-03-02 01:32:50 PM] training complete
# [2023-03-02 01:41:19 PM] training....
# [2023-03-02 01:41:19 PM] training complete
# [2023-03-02 01:41:19 PM] training replay buffer....
# [2023-03-02 01:41:19 PM] training complete
# [2023-03-02 01:41:30 PM] training....
# [2023-03-02 01:41:30 PM] training complete
# [2023-03-02 01:41:31 PM] training....
# [2023-03-02 01:41:31 PM] training complete
# [2023-03-02 01:41:32 PM] training....
# [2023-03-02 01:41:32 PM] training complete
# [2023-03-02 01:41:33 PM] training....
# [2023-03-02 01:41:34 PM] training complete
# [2023-03-02 01:41:34 PM] training....
# [2023-03-02 01:41:35 PM] training complete
# [2023-03-02 01:50:37 PM] training....
# [2023-03-02 01:50:38 PM] training complete
# [2023-03-02 01:50:38 PM] training replay buffer....
# [2023-03-02 01:50:38 PM] training complete
# [2023-03-02 01:50:48 PM] training....
# [2023-03-02 01:50:49 PM] training complete
# [2023-03-02 01:50:49 PM] training....
# [2023-03-02 01:50:50 PM] training complete
# [2023-03-02 01:50:51 PM] training....
# [2023-03-02 01:50:51 PM] training complete
# [2023-03-02 01:59:22 PM] training....
# [2023-03-02 01:59:23 PM] training complete
# [2023-03-02 01:59:23 PM] training replay buffer....
# [2023-03-02 01:59:23 PM] training complete
# [2023-03-02 01:59:33 PM] training....
# [2023-03-02 01:59:33 PM] training complete
# [2023-03-02 01:59:34 PM] training....
# [2023-03-02 01:59:35 PM] training complete
# [2023-03-02 01:59:35 PM] training....
# [2023-03-02 01:59:36 PM] training complete
# [2023-03-02 01:59:37 PM] training....
# [2023-03-02 01:59:37 PM] training complete
# [2023-03-02 02:08:00 PM] training....
# [2023-03-02 02:08:01 PM] training complete
# [2023-03-02 02:08:01 PM] training replay buffer....
# [2023-03-02 02:08:01 PM] training complete
# [2023-03-02 02:08:11 PM] training....
# [2023-03-02 02:08:11 PM] training complete
# [2023-03-02 02:08:12 PM] training....
# [2023-03-02 02:08:13 PM] training complete
# [2023-03-02 02:08:13 PM] training....
# [2023-03-02 02:08:14 PM] training complete
# [2023-03-02 02:08:15 PM] training....
# [2023-03-02 02:08:15 PM] training complete
# [2023-03-02 02:17:01 PM] training....
# [2023-03-02 02:17:01 PM] training complete
# [2023-03-02 02:17:01 PM] training replay buffer....
# [2023-03-02 02:17:01 PM] training complete
# [2023-03-02 02:17:12 PM] training....
# [2023-03-02 02:17:13 PM] training complete
# [2023-03-02 02:17:13 PM] training....
# [2023-03-02 02:17:14 PM] training complete
# [2023-03-02 02:25:35 PM] training....
# [2023-03-02 02:25:36 PM] training complete
# [2023-03-02 02:25:36 PM] training replay buffer....
# [2023-03-02 02:25:36 PM] training complete
# [2023-03-02 02:25:46 PM] training....
# [2023-03-02 02:25:47 PM] training complete
# [2023-03-02 02:25:48 PM] training....
# [2023-03-02 02:25:48 PM] training complete
# [2023-03-02 02:25:49 PM] training....
# [2023-03-02 02:25:49 PM] training complete
# [2023-03-02 02:25:50 PM] training....
# [2023-03-02 02:25:50 PM] training complete
# [2023-03-02 02:34:56 PM] training....
# [2023-03-02 02:34:57 PM] training complete
# [2023-03-02 02:34:57 PM] training replay buffer....
# [2023-03-02 02:34:57 PM] training complete
# [2023-03-02 02:35:07 PM] training....
# [2023-03-02 02:35:08 PM] training complete
# [2023-03-02 02:35:09 PM] training....
# [2023-03-02 02:35:09 PM] training complete
# [2023-03-02 02:35:10 PM] training....
# [2023-03-02 02:35:10 PM] training complete
# [2023-03-02 02:35:11 PM] training....
# [2023-03-02 02:35:12 PM] training complete
# [2023-03-02 02:44:05 PM] training....
# [2023-03-02 02:44:05 PM] training complete
# [2023-03-02 02:44:05 PM] training replay buffer....
# [2023-03-02 02:44:05 PM] training complete
# [2023-03-02 02:44:16 PM] training....
# [2023-03-02 02:44:16 PM] training complete
# [2023-03-02 02:44:17 PM] training....
# [2023-03-02 02:44:17 PM] training complete
# [2023-03-02 02:44:18 PM] training....
# [2023-03-02 02:44:19 PM] training complete
# [2023-03-02 02:52:35 PM] training....
# [2023-03-02 02:52:35 PM] training complete
# [2023-03-02 02:52:35 PM] training replay buffer....
# [2023-03-02 02:52:35 PM] training complete
# [2023-03-02 02:52:46 PM] training....
# [2023-03-02 02:52:46 PM] training complete
# [2023-03-02 02:52:47 PM] training....
# [2023-03-02 02:52:47 PM] training complete
# [2023-03-02 02:52:48 PM] training....
# [2023-03-02 02:52:49 PM] training complete
# [2023-03-02 03:02:07 PM] training....
# [2023-03-02 03:02:07 PM] training complete
# [2023-03-02 03:02:07 PM] training replay buffer....
# [2023-03-02 03:02:07 PM] training complete
# [2023-03-02 03:02:17 PM] training....
# [2023-03-02 03:02:18 PM] training complete
# [2023-03-02 03:02:18 PM] training....
# [2023-03-02 03:02:19 PM] training complete
# [2023-03-02 03:02:20 PM] training....
# [2023-03-02 03:02:20 PM] training complete
# [2023-03-02 03:02:21 PM] training....
# [2023-03-02 03:02:21 PM] training complete
# [2023-03-02 03:02:22 PM] training....
# [2023-03-02 03:02:22 PM] training complete
# [2023-03-02 03:10:53 PM] training....
# [2023-03-02 03:10:53 PM] training complete
# [2023-03-02 03:10:53 PM] training replay buffer....
# [2023-03-02 03:10:53 PM] training complete
# [2023-03-02 03:11:04 PM] training....
# [2023-03-02 03:11:04 PM] training complete
# [2023-03-02 03:11:05 PM] training....
# [2023-03-02 03:11:05 PM] training complete
# [2023-03-02 03:11:06 PM] training....
# [2023-03-02 03:11:06 PM] training complete
# [2023-03-02 03:11:07 PM] training....
# [2023-03-02 03:11:08 PM] training complete
# [2023-03-02 03:11:09 PM] training....
# [2023-03-02 03:11:09 PM] training complete
# [2023-03-02 03:19:32 PM] training....
# [2023-03-02 03:19:33 PM] training complete
# [2023-03-02 03:19:33 PM] training replay buffer....
# [2023-03-02 03:19:33 PM] training complete
# [2023-03-02 03:19:43 PM] training....
# [2023-03-02 03:19:43 PM] training complete
# [2023-03-02 03:19:44 PM] training....
# [2023-03-02 03:19:45 PM] training complete
# [2023-03-02 03:19:45 PM] training....
# [2023-03-02 03:19:46 PM] training complete
# [2023-03-02 03:19:47 PM] training....
# [2023-03-02 03:19:47 PM] training complete
# [2023-03-02 03:28:27 PM] training....
# [2023-03-02 03:28:27 PM] training complete
# [2023-03-02 03:28:27 PM] training replay buffer....
# [2023-03-02 03:28:27 PM] training complete
# [2023-03-02 03:28:38 PM] training....
# [2023-03-02 03:28:38 PM] training complete
# [2023-03-02 03:28:39 PM] training....
# [2023-03-02 03:28:39 PM] training complete
# [2023-03-02 03:28:40 PM] training....
# [2023-03-02 03:28:41 PM] training complete
# [2023-03-02 03:28:41 PM] training....
# [2023-03-02 03:28:42 PM] training complete
# [2023-03-02 03:38:22 PM] training....
# [2023-03-02 03:38:22 PM] training complete
# [2023-03-02 03:38:22 PM] training replay buffer....
# [2023-03-02 03:38:22 PM] training complete
# [2023-03-02 03:38:32 PM] training....
# [2023-03-02 03:38:32 PM] training complete
# [2023-03-02 03:38:33 PM] training....
# [2023-03-02 03:38:34 PM] training complete
# [2023-03-02 03:38:34 PM] training....
# [2023-03-02 03:38:35 PM] training complete
# [2023-03-02 03:38:36 PM] training....
# [2023-03-02 03:38:36 PM] training complete
# [2023-03-02 03:47:13 PM] training....
# [2023-03-02 03:47:13 PM] training complete
# [2023-03-02 03:47:13 PM] training replay buffer....
# [2023-03-02 03:47:13 PM] training complete
# [2023-03-02 03:47:23 PM] training....
# [2023-03-02 03:47:24 PM] training complete
# [2023-03-02 03:47:25 PM] training....
# [2023-03-02 03:47:25 PM] training complete
# [2023-03-02 03:47:26 PM] training....
# [2023-03-02 03:47:26 PM] training complete
# [2023-03-02 03:47:27 PM] training....
# [2023-03-02 03:47:27 PM] training complete
# [2023-03-02 03:56:12 PM] training....
# [2023-03-02 03:56:13 PM] training complete
# [2023-03-02 03:56:13 PM] training replay buffer....
# [2023-03-02 03:56:13 PM] training complete
# [2023-03-02 03:56:23 PM] training....
# [2023-03-02 03:56:24 PM] training complete
# [2023-03-02 03:56:25 PM] training....
# [2023-03-02 03:56:25 PM] training complete
# [2023-03-02 03:56:26 PM] training....
# [2023-03-02 03:56:26 PM] training complete
# [2023-03-02 04:05:20 PM] training....
# [2023-03-02 04:05:21 PM] training complete
# [2023-03-02 04:05:21 PM] training replay buffer....
# [2023-03-02 04:05:21 PM] training complete
# [2023-03-02 04:05:31 PM] training....
# [2023-03-02 04:05:32 PM] training complete
# [2023-03-02 04:05:32 PM] training....
# [2023-03-02 04:05:33 PM] training complete
# [2023-03-02 04:05:34 PM] training....
# [2023-03-02 04:05:34 PM] training complete
# [2023-03-02 04:14:35 PM] training....
# [2023-03-02 04:14:35 PM] training complete
# [2023-03-02 04:14:35 PM] training replay buffer....
# [2023-03-02 04:14:35 PM] training complete
# [2023-03-02 04:14:45 PM] training....
# [2023-03-02 04:14:46 PM] training complete
# [2023-03-02 04:14:47 PM] training....
# [2023-03-02 04:14:47 PM] training complete
# [2023-03-02 04:14:48 PM] training....
# [2023-03-02 04:14:48 PM] training complete
# [2023-03-02 04:14:49 PM] training....
# [2023-03-02 04:14:49 PM] training complete
# [2023-03-02 04:23:08 PM] training....
# [2023-03-02 04:23:08 PM] training complete
# [2023-03-02 04:23:08 PM] training replay buffer....
# [2023-03-02 04:23:08 PM] training complete
# [2023-03-02 04:23:18 PM] training....
# [2023-03-02 04:23:19 PM] training complete
# [2023-03-02 04:23:20 PM] training....
# [2023-03-02 04:23:20 PM] training complete
# [2023-03-02 04:23:21 PM] training....
# [2023-03-02 04:23:21 PM] training complete
# [2023-03-02 04:31:35 PM] training....
# [2023-03-02 04:31:35 PM] training complete
# [2023-03-02 04:31:35 PM] training replay buffer....
# [2023-03-02 04:31:35 PM] training complete
# [2023-03-02 04:31:45 PM] training....
# [2023-03-02 04:31:46 PM] training complete
# [2023-03-02 04:31:47 PM] training....
# [2023-03-02 04:31:47 PM] training complete
# [2023-03-02 04:31:48 PM] training....
# [2023-03-02 04:31:48 PM] training complete
# [2023-03-02 04:41:06 PM] training....
# [2023-03-02 04:41:06 PM] training complete
# [2023-03-02 04:41:06 PM] training replay buffer....
# [2023-03-02 04:41:06 PM] training complete
# [2023-03-02 04:41:17 PM] training....
# [2023-03-02 04:41:17 PM] training complete
# [2023-03-02 04:41:18 PM] training....
# [2023-03-02 04:41:18 PM] training complete
# [2023-03-02 04:41:19 PM] training....
# [2023-03-02 04:41:20 PM] training complete
# [2023-03-02 04:41:20 PM] training....
# [2023-03-02 04:41:21 PM] training complete
# [2023-03-02 04:50:10 PM] training....
# [2023-03-02 04:50:10 PM] training complete
# [2023-03-02 04:50:10 PM] training replay buffer....
# [2023-03-02 04:50:10 PM] training complete
# [2023-03-02 04:50:21 PM] training....
# [2023-03-02 04:50:21 PM] training complete
# [2023-03-02 04:50:22 PM] training....
# [2023-03-02 04:50:22 PM] training complete
# [2023-03-02 04:50:23 PM] training....
# [2023-03-02 04:50:23 PM] training complete
# [2023-03-02 04:58:51 PM] training....
# [2023-03-02 04:58:52 PM] training complete
# [2023-03-02 04:58:52 PM] training replay buffer....
# [2023-03-02 04:58:52 PM] training complete
# [2023-03-02 04:59:02 PM] training....
# [2023-03-02 04:59:03 PM] training complete
# [2023-03-02 04:59:03 PM] training....
# [2023-03-02 04:59:04 PM] training complete
# [2023-03-02 04:59:05 PM] training....
# [2023-03-02 04:59:05 PM] training complete
# [2023-03-02 04:59:06 PM] training....
# [2023-03-02 04:59:06 PM] training complete
# [2023-03-02 05:07:28 PM] training....
# [2023-03-02 05:07:28 PM] training complete
# [2023-03-02 05:07:28 PM] training replay buffer....
# [2023-03-02 05:07:28 PM] training complete
# [2023-03-02 05:07:38 PM] training....
# [2023-03-02 05:07:39 PM] training complete
# [2023-03-02 05:07:40 PM] training....
# [2023-03-02 05:07:40 PM] training complete
# [2023-03-02 05:07:41 PM] training....
# [2023-03-02 05:07:41 PM] training complete
# [2023-03-02 05:07:42 PM] training....
# [2023-03-02 05:07:42 PM] training complete
# [2023-03-02 05:15:54 PM] training....
# [2023-03-02 05:15:54 PM] training complete
# [2023-03-02 05:15:54 PM] training replay buffer....
# [2023-03-02 05:15:54 PM] training complete
# [2023-03-02 05:16:05 PM] training....
# [2023-03-02 05:16:05 PM] training complete
# [2023-03-02 05:16:06 PM] training....
# [2023-03-02 05:16:06 PM] training complete
# [2023-03-02 05:16:07 PM] training....
# [2023-03-02 05:16:08 PM] training complete
# [2023-03-02 05:16:08 PM] training....
# [2023-03-02 05:16:09 PM] training complete
# [2023-03-02 05:24:39 PM] training....
# [2023-03-02 05:24:39 PM] training complete
# [2023-03-02 05:24:39 PM] training replay buffer....
# [2023-03-02 05:24:39 PM] training complete
# [2023-03-02 05:24:50 PM] training....
# [2023-03-02 05:24:50 PM] training complete
# [2023-03-02 05:24:51 PM] training....
# [2023-03-02 05:24:51 PM] training complete
# [2023-03-02 05:24:52 PM] training....
# [2023-03-02 05:24:52 PM] training complete
# [2023-03-02 05:24:53 PM] training....
# [2023-03-02 05:24:54 PM] training complete
# [2023-03-02 05:33:23 PM] training....
# [2023-03-02 05:33:23 PM] training complete
# [2023-03-02 05:33:23 PM] training replay buffer....
# [2023-03-02 05:33:23 PM] training complete
# [2023-03-02 05:33:33 PM] training....
# [2023-03-02 05:33:34 PM] training complete
# [2023-03-02 05:33:34 PM] training....
# [2023-03-02 05:33:35 PM] training complete
# [2023-03-02 05:33:36 PM] training....
# [2023-03-02 05:33:36 PM] training complete
# [2023-03-02 05:33:37 PM] training....
# [2023-03-02 05:33:37 PM] training complete
# [2023-03-02 05:33:38 PM] training....
# [2023-03-02 05:33:38 PM] training complete
# [2023-03-02 05:42:33 PM] training....
# [2023-03-02 05:42:34 PM] training complete
# [2023-03-02 05:42:34 PM] training replay buffer....
# [2023-03-02 05:42:34 PM] training complete
# [2023-03-02 05:42:44 PM] training....
# [2023-03-02 05:42:45 PM] training complete
# [2023-03-02 05:42:45 PM] training....
# [2023-03-02 05:42:46 PM] training complete
# [2023-03-02 05:42:47 PM] training....
# [2023-03-02 05:42:47 PM] training complete
# [2023-03-02 05:42:48 PM] training....
# [2023-03-02 05:42:48 PM] training complete
# [2023-03-02 05:51:40 PM] training....
# [2023-03-02 05:51:40 PM] training complete
# [2023-03-02 05:51:40 PM] training replay buffer....
# [2023-03-02 05:51:40 PM] training complete
# [2023-03-02 05:51:50 PM] training....
# [2023-03-02 05:51:50 PM] training complete
# [2023-03-02 05:51:51 PM] training....
# [2023-03-02 05:51:52 PM] training complete
# [2023-03-02 05:51:52 PM] training....
# [2023-03-02 05:51:53 PM] training complete
# [2023-03-02 05:51:54 PM] training....
# [2023-03-02 05:51:54 PM] training complete
# [2023-03-02 05:51:55 PM] training....
# [2023-03-02 05:51:55 PM] training complete
# [2023-03-02 06:00:52 PM] training....
# [2023-03-02 06:00:52 PM] training complete
# [2023-03-02 06:00:52 PM] training replay buffer....
# [2023-03-02 06:00:52 PM] training complete
# [2023-03-02 06:01:02 PM] training....
# [2023-03-02 06:01:03 PM] training complete
# [2023-03-02 06:01:04 PM] training....
# [2023-03-02 06:01:04 PM] training complete
# [2023-03-02 06:01:05 PM] training....
# [2023-03-02 06:01:05 PM] training complete
# [2023-03-02 06:01:06 PM] training....
# [2023-03-02 06:01:06 PM] training complete
# [2023-03-02 06:10:23 PM] training....
# [2023-03-02 06:10:23 PM] training complete
# [2023-03-02 06:10:23 PM] training replay buffer....
# [2023-03-02 06:10:23 PM] training complete
# [2023-03-02 06:10:34 PM] training....
# [2023-03-02 06:10:34 PM] training complete
# [2023-03-02 06:10:35 PM] training....
# [2023-03-02 06:10:35 PM] training complete
# [2023-03-02 06:10:36 PM] training....
# [2023-03-02 06:10:37 PM] training complete
# [2023-03-02 06:10:37 PM] training....
# [2023-03-02 06:10:38 PM] training complete
# [2023-03-02 06:10:39 PM] training....
# [2023-03-02 06:10:39 PM] training complete
# [2023-03-02 06:19:19 PM] training....
# [2023-03-02 06:19:20 PM] training complete
# [2023-03-02 06:19:20 PM] training replay buffer....
# [2023-03-02 06:19:20 PM] training complete
# [2023-03-02 06:19:30 PM] training....
# [2023-03-02 06:19:31 PM] training complete
# [2023-03-02 06:19:31 PM] training....
# [2023-03-02 06:19:32 PM] training complete
# [2023-03-02 06:28:07 PM] training....
# [2023-03-02 06:28:08 PM] training complete
# [2023-03-02 06:28:08 PM] training replay buffer....
# [2023-03-02 06:28:08 PM] training complete
# [2023-03-02 06:28:18 PM] training....
# [2023-03-02 06:28:18 PM] training complete
# [2023-03-02 06:28:19 PM] training....
# [2023-03-02 06:28:19 PM] training complete
# [2023-03-02 06:28:20 PM] training....
# [2023-03-02 06:28:21 PM] training complete
# [2023-03-02 06:28:21 PM] training....
# [2023-03-02 06:28:22 PM] training complete
# [2023-03-02 06:28:23 PM] training....
# [2023-03-02 06:28:23 PM] training complete
# [2023-03-02 06:37:36 PM] training....
# [2023-03-02 06:37:37 PM] training complete
# [2023-03-02 06:37:37 PM] training replay buffer....
# [2023-03-02 06:37:37 PM] training complete
# [2023-03-02 06:37:47 PM] training....
# [2023-03-02 06:37:48 PM] training complete
# [2023-03-02 06:37:48 PM] training....
# [2023-03-02 06:37:49 PM] training complete
# [2023-03-02 06:37:50 PM] training....
# [2023-03-02 06:37:50 PM] training complete
# [2023-03-02 06:37:51 PM] training....
# [2023-03-02 06:37:51 PM] training complete
# [2023-03-02 06:46:10 PM] training....
# [2023-03-02 06:46:11 PM] training complete
# [2023-03-02 06:46:11 PM] training replay buffer....
# [2023-03-02 06:46:11 PM] training complete
# [2023-03-02 06:46:21 PM] training....
# [2023-03-02 06:46:21 PM] training complete
# [2023-03-02 06:46:22 PM] training....
# [2023-03-02 06:46:22 PM] training complete
# [2023-03-02 06:46:23 PM] training....
# [2023-03-02 06:46:24 PM] training complete
# [2023-03-02 06:46:24 PM] training....
# [2023-03-02 06:46:25 PM] training complete
# [2023-03-02 06:55:16 PM] training....
# [2023-03-02 06:55:17 PM] training complete
# [2023-03-02 06:55:17 PM] training replay buffer....
# [2023-03-02 06:55:17 PM] training complete
# [2023-03-02 06:55:27 PM] training....
# [2023-03-02 06:55:27 PM] training complete
# [2023-03-02 06:55:28 PM] training....
# [2023-03-02 06:55:28 PM] training complete
# [2023-03-02 06:55:29 PM] training....
# [2023-03-02 06:55:30 PM] training complete
# [2023-03-02 06:55:30 PM] training....
# [2023-03-02 06:55:31 PM] training complete
# [2023-03-02 06:55:32 PM] training....
# [2023-03-02 06:55:32 PM] training complete
# [2023-03-02 07:03:53 PM] training....
# [2023-03-02 07:03:53 PM] training complete
# [2023-03-02 07:03:53 PM] training replay buffer....
# [2023-03-02 07:03:53 PM] training complete
# [2023-03-02 07:04:04 PM] training....
# [2023-03-02 07:04:04 PM] training complete
# [2023-03-02 07:04:05 PM] training....
# [2023-03-02 07:04:06 PM] training complete
# [2023-03-02 07:04:07 PM] training....
# [2023-03-02 07:04:07 PM] training complete
# [2023-03-02 07:12:48 PM] training....
# [2023-03-02 07:12:48 PM] training complete
# [2023-03-02 07:12:48 PM] training replay buffer....
# [2023-03-02 07:12:48 PM] training complete
# [2023-03-02 07:12:58 PM] training....
# [2023-03-02 07:12:59 PM] training complete
# [2023-03-02 07:13:00 PM] training....
# [2023-03-02 07:13:00 PM] training complete
# [2023-03-02 07:13:01 PM] training....
# [2023-03-02 07:13:01 PM] training complete
# [2023-03-02 07:13:02 PM] training....
# [2023-03-02 07:13:02 PM] training complete
# [2023-03-02 07:13:03 PM] training....
# [2023-03-02 07:13:04 PM] training complete
# [2023-03-02 07:21:57 PM] training....
# [2023-03-02 07:21:58 PM] training complete
# [2023-03-02 07:21:58 PM] training replay buffer....
# [2023-03-02 07:21:58 PM] training complete
# [2023-03-02 07:22:09 PM] training....
# [2023-03-02 07:22:09 PM] training complete
# [2023-03-02 07:22:10 PM] training....
# [2023-03-02 07:22:10 PM] training complete
# [2023-03-02 07:22:11 PM] training....
# [2023-03-02 07:22:12 PM] training complete
# [2023-03-02 07:31:19 PM] training....
# [2023-03-02 07:31:20 PM] training complete
# [2023-03-02 07:31:20 PM] training replay buffer....
# [2023-03-02 07:31:20 PM] training complete
# [2023-03-02 07:31:30 PM] training....
# [2023-03-02 07:31:31 PM] training complete
# [2023-03-02 07:31:31 PM] training....
# [2023-03-02 07:31:32 PM] training complete
# [2023-03-02 07:31:33 PM] training....
# [2023-03-02 07:31:33 PM] training complete
# [2023-03-02 07:31:34 PM] training....
# [2023-03-02 07:31:34 PM] training complete
# [2023-03-02 07:40:53 PM] training....
# [2023-03-02 07:40:53 PM] training complete
# [2023-03-02 07:40:53 PM] training replay buffer....
# [2023-03-02 07:40:53 PM] training complete
# [2023-03-02 07:41:04 PM] training....
# [2023-03-02 07:41:04 PM] training complete
# [2023-03-02 07:41:05 PM] training....
# [2023-03-02 07:41:05 PM] training complete
# [2023-03-02 07:41:06 PM] training....
# [2023-03-02 07:41:07 PM] training complete
# [2023-03-02 07:41:07 PM] training....
# [2023-03-02 07:41:08 PM] training complete
# [2023-03-02 07:49:56 PM] training....
# [2023-03-02 07:49:57 PM] training complete
# [2023-03-02 07:49:57 PM] training replay buffer....
# [2023-03-02 07:49:57 PM] training complete
# [2023-03-02 07:50:07 PM] training....
# [2023-03-02 07:50:08 PM] training complete
# [2023-03-02 07:50:09 PM] training....
# [2023-03-02 07:50:09 PM] training complete
# [2023-03-02 07:50:10 PM] training....
# [2023-03-02 07:50:10 PM] training complete
# [2023-03-02 07:50:11 PM] training....
# [2023-03-02 07:50:12 PM] training complete
# [2023-03-02 07:59:07 PM] training....
# [2023-03-02 07:59:07 PM] training complete
# [2023-03-02 07:59:07 PM] training replay buffer....
# [2023-03-02 07:59:07 PM] training complete
# [2023-03-02 07:59:18 PM] training....
# [2023-03-02 07:59:18 PM] training complete
# [2023-03-02 07:59:19 PM] training....
# [2023-03-02 07:59:19 PM] training complete
# [2023-03-02 07:59:20 PM] training....
# [2023-03-02 07:59:20 PM] training complete
# [2023-03-02 07:59:21 PM] training....
# [2023-03-02 07:59:22 PM] training complete
# [2023-03-02 08:09:41 PM] training....
# [2023-03-02 08:09:42 PM] training complete
# [2023-03-02 08:09:42 PM] training replay buffer....
# [2023-03-02 08:09:42 PM] training complete
# [2023-03-02 08:09:52 PM] training....
# [2023-03-02 08:09:53 PM] training complete
# [2023-03-02 08:09:53 PM] training....
# [2023-03-02 08:09:54 PM] training complete
# [2023-03-02 08:09:54 PM] training....
# [2023-03-02 08:09:55 PM] training complete
# [2023-03-02 08:09:55 PM] training....
# [2023-03-02 08:09:55 PM] training complete
# [2023-03-02 08:09:56 PM] training....
# [2023-03-02 08:09:56 PM] training complete
# [2023-03-02 08:19:48 PM] training....
# [2023-03-02 08:19:48 PM] training complete
# [2023-03-02 08:19:48 PM] training replay buffer....
# [2023-03-02 08:19:48 PM] training complete
# [2023-03-02 08:19:59 PM] training....
# [2023-03-02 08:19:59 PM] training complete
# [2023-03-02 08:20:00 PM] training....
# [2023-03-02 08:20:00 PM] training complete
# [2023-03-02 08:20:01 PM] training....
# [2023-03-02 08:20:01 PM] training complete
# [2023-03-02 08:20:02 PM] training....
# [2023-03-02 08:20:03 PM] training complete
# [2023-03-02 08:20:03 PM] training....
# [2023-03-02 08:20:04 PM] training complete
# [2023-03-02 08:28:52 PM] training....
# [2023-03-02 08:28:52 PM] training complete
# [2023-03-02 08:28:52 PM] training replay buffer....
# [2023-03-02 08:28:52 PM] training complete
# [2023-03-02 08:29:02 PM] training....
# [2023-03-02 08:29:03 PM] training complete
# [2023-03-02 08:29:03 PM] training....
# [2023-03-02 08:29:04 PM] training complete
# [2023-03-02 08:29:05 PM] training....
# [2023-03-02 08:29:05 PM] training complete
# [2023-03-02 08:29:06 PM] training....
# [2023-03-02 08:29:06 PM] training complete
# [2023-03-02 08:29:07 PM] training....
# [2023-03-02 08:29:07 PM] training complete
# [2023-03-02 08:37:34 PM] training....
# [2023-03-02 08:37:35 PM] training complete
# [2023-03-02 08:37:35 PM] training replay buffer....
# [2023-03-02 08:37:35 PM] training complete
# [2023-03-02 08:37:45 PM] training....
# [2023-03-02 08:37:46 PM] training complete
# [2023-03-02 08:37:46 PM] training....
# [2023-03-02 08:37:47 PM] training complete
# [2023-03-02 08:37:48 PM] training....
# [2023-03-02 08:37:48 PM] training complete
# [2023-03-02 08:46:08 PM] training....
# [2023-03-02 08:46:09 PM] training complete
# [2023-03-02 08:46:09 PM] training replay buffer....
# [2023-03-02 08:46:09 PM] training complete
# [2023-03-02 08:46:19 PM] training....
# [2023-03-02 08:46:20 PM] training complete
# [2023-03-02 08:46:20 PM] training....
# [2023-03-02 08:46:21 PM] training complete
# [2023-03-02 08:46:22 PM] training....
# [2023-03-02 08:46:22 PM] training complete
# [2023-03-02 08:54:34 PM] training....
# [2023-03-02 08:54:34 PM] training complete
# [2023-03-02 08:54:34 PM] training replay buffer....
# [2023-03-02 08:54:34 PM] training complete
# [2023-03-02 08:54:44 PM] training....
# [2023-03-02 08:54:45 PM] training complete
# [2023-03-02 08:54:46 PM] training....
# [2023-03-02 08:54:46 PM] training complete
# [2023-03-02 08:54:47 PM] training....
# [2023-03-02 08:54:47 PM] training complete
# [2023-03-02 09:02:46 PM] training....
# [2023-03-02 09:02:47 PM] training complete
# [2023-03-02 09:02:47 PM] training replay buffer....
# [2023-03-02 09:02:47 PM] training complete
# [2023-03-02 09:02:58 PM] training....
# [2023-03-02 09:02:58 PM] training complete
# [2023-03-02 09:02:59 PM] training....
# [2023-03-02 09:02:59 PM] training complete
# [2023-03-02 09:03:00 PM] training....
# [2023-03-02 09:03:00 PM] training complete
# [2023-03-02 09:03:01 PM] training....
# [2023-03-02 09:03:02 PM] training complete
# [2023-03-02 09:11:18 PM] training....
# [2023-03-02 09:11:18 PM] training complete
# [2023-03-02 09:11:18 PM] training replay buffer....
# [2023-03-02 09:11:18 PM] training complete
# [2023-03-02 09:11:28 PM] training....
# [2023-03-02 09:11:29 PM] training complete
# [2023-03-02 09:11:29 PM] training....
# [2023-03-02 09:11:30 PM] training complete
# [2023-03-02 09:11:31 PM] training....
# [2023-03-02 09:11:31 PM] training complete
# [2023-03-02 09:11:32 PM] training....
# [2023-03-02 09:11:32 PM] training complete
# [2023-03-02 09:20:31 PM] training....
# [2023-03-02 09:20:32 PM] training complete
# [2023-03-02 09:20:32 PM] training replay buffer....
# [2023-03-02 09:20:32 PM] training complete
# [2023-03-02 09:20:42 PM] training....
# [2023-03-02 09:20:43 PM] training complete
# [2023-03-02 09:20:44 PM] training....
# [2023-03-02 09:20:44 PM] training complete
# [2023-03-02 09:29:42 PM] training....
# [2023-03-02 09:29:42 PM] training complete
# [2023-03-02 09:29:42 PM] training replay buffer....
# [2023-03-02 09:29:42 PM] training complete
# [2023-03-02 09:29:52 PM] training....
# [2023-03-02 09:29:53 PM] training complete
# [2023-03-02 09:29:54 PM] training....
# [2023-03-02 09:29:54 PM] training complete
# [2023-03-02 09:29:55 PM] training....
# [2023-03-02 09:29:55 PM] training complete
# [2023-03-02 09:39:00 PM] training....
# [2023-03-02 09:39:01 PM] training complete
# [2023-03-02 09:39:01 PM] training replay buffer....
# [2023-03-02 09:39:01 PM] training complete
# [2023-03-02 09:39:11 PM] training....
# [2023-03-02 09:39:11 PM] training complete
# [2023-03-02 09:39:12 PM] training....
# [2023-03-02 09:39:12 PM] training complete
# [2023-03-02 09:39:13 PM] training....
# [2023-03-02 09:39:14 PM] training complete
# [2023-03-02 09:39:14 PM] training....
# [2023-03-02 09:39:15 PM] training complete
# [2023-03-02 09:39:16 PM] training....
# [2023-03-02 09:39:16 PM] training complete
# [2023-03-02 09:47:29 PM] training....
# [2023-03-02 09:47:29 PM] training complete
# [2023-03-02 09:47:29 PM] training replay buffer....
# [2023-03-02 09:47:29 PM] training complete
# [2023-03-02 09:47:40 PM] training....
# [2023-03-02 09:47:40 PM] training complete
# [2023-03-02 09:47:41 PM] training....
# [2023-03-02 09:47:42 PM] training complete
# [2023-03-02 09:47:43 PM] training....
# [2023-03-02 09:47:43 PM] training complete
# [2023-03-02 09:55:34 PM] training....
# [2023-03-02 09:55:35 PM] training complete
# [2023-03-02 09:55:35 PM] training replay buffer....
# [2023-03-02 09:55:35 PM] training complete
# [2023-03-02 09:55:45 PM] training....
# [2023-03-02 09:55:45 PM] training complete
# [2023-03-02 09:55:46 PM] training....
# [2023-03-02 09:55:47 PM] training complete
# [2023-03-02 09:55:47 PM] training....
# [2023-03-02 09:55:48 PM] training complete
# [2023-03-02 09:55:49 PM] training....
# [2023-03-02 09:55:49 PM] training complete
# [2023-03-02 10:04:25 PM] training....
# [2023-03-02 10:04:26 PM] training complete
# [2023-03-02 10:04:26 PM] training replay buffer....
# [2023-03-02 10:04:26 PM] training complete
# [2023-03-02 10:04:36 PM] training....
# [2023-03-02 10:04:36 PM] training complete
# [2023-03-02 10:04:37 PM] training....
# [2023-03-02 10:04:38 PM] training complete
# [2023-03-02 10:04:38 PM] training....
# [2023-03-02 10:04:39 PM] training complete
# [2023-03-02 10:04:40 PM] training....
# [2023-03-02 10:04:40 PM] training complete
# [2023-03-02 10:04:41 PM] training....
# [2023-03-02 10:04:42 PM] training complete
# [2023-03-02 10:13:47 PM] training....
# [2023-03-02 10:13:48 PM] training complete
# [2023-03-02 10:13:48 PM] training replay buffer....
# [2023-03-02 10:13:48 PM] training complete
# [2023-03-02 10:13:58 PM] training....
# [2023-03-02 10:13:58 PM] training complete
# [2023-03-02 10:13:59 PM] training....
# [2023-03-02 10:13:59 PM] training complete
# [2023-03-02 10:14:00 PM] training....
# [2023-03-02 10:14:01 PM] training complete
# [2023-03-02 10:14:01 PM] training....
# [2023-03-02 10:14:02 PM] training complete
# [2023-03-02 10:14:03 PM] training....
# [2023-03-02 10:14:03 PM] training complete
# [2023-03-02 10:23:03 PM] training....
# [2023-03-02 10:23:04 PM] training complete
# [2023-03-02 10:23:04 PM] training replay buffer....
# [2023-03-02 10:23:04 PM] training complete
# [2023-03-02 10:23:14 PM] training....
# [2023-03-02 10:23:15 PM] training complete
# [2023-03-02 10:23:15 PM] training....
# [2023-03-02 10:23:16 PM] training complete
# [2023-03-02 10:23:17 PM] training....
# [2023-03-02 10:23:17 PM] training complete
# [2023-03-02 10:23:18 PM] training....
# [2023-03-02 10:23:18 PM] training complete
# [2023-03-02 10:33:00 PM] training....
# [2023-03-02 10:33:00 PM] training complete
# [2023-03-02 10:33:00 PM] training replay buffer....
# [2023-03-02 10:33:00 PM] training complete
# [2023-03-02 10:33:10 PM] training....
# [2023-03-02 10:33:11 PM] training complete
# [2023-03-02 10:33:12 PM] training....
# [2023-03-02 10:33:12 PM] training complete
# [2023-03-02 10:33:13 PM] training....
# [2023-03-02 10:33:13 PM] training complete
# [2023-03-02 10:33:14 PM] training....
# [2023-03-02 10:33:14 PM] training complete
# [2023-03-02 10:33:15 PM] training....
# [2023-03-02 10:33:16 PM] training complete
# [2023-03-02 10:42:17 PM] training....
# [2023-03-02 10:42:17 PM] training complete
# [2023-03-02 10:42:17 PM] training replay buffer....
# [2023-03-02 10:42:17 PM] training complete
# [2023-03-02 10:42:28 PM] training....
# [2023-03-02 10:42:28 PM] training complete
# [2023-03-02 10:42:29 PM] training....
# [2023-03-02 10:42:29 PM] training complete
# [2023-03-02 10:42:30 PM] training....
# [2023-03-02 10:42:30 PM] training complete
# [2023-03-02 10:42:31 PM] training....
# [2023-03-02 10:42:32 PM] training complete
# [2023-03-02 10:42:32 PM] training....
# [2023-03-02 10:42:33 PM] training complete
# [2023-03-02 10:50:53 PM] training....
# [2023-03-02 10:50:53 PM] training complete
# [2023-03-02 10:50:53 PM] training replay buffer....
# [2023-03-02 10:50:53 PM] training complete
# [2023-03-02 10:51:04 PM] training....
# [2023-03-02 10:51:04 PM] training complete
# [2023-03-02 10:51:05 PM] training....
# [2023-03-02 10:51:05 PM] training complete
# [2023-03-02 10:51:06 PM] training....
# [2023-03-02 10:51:06 PM] training complete
# [2023-03-02 10:59:41 PM] training....
# [2023-03-02 10:59:41 PM] training complete
# [2023-03-02 10:59:41 PM] training replay buffer....
# [2023-03-02 10:59:41 PM] training complete
# [2023-03-02 10:59:52 PM] training....
# [2023-03-02 10:59:52 PM] training complete
# [2023-03-02 10:59:53 PM] training....
# [2023-03-02 10:59:53 PM] training complete
# [2023-03-02 10:59:54 PM] training....
# [2023-03-02 10:59:54 PM] training complete
# [2023-03-02 10:59:55 PM] training....
# [2023-03-02 10:59:55 PM] training complete
# [2023-03-02 11:08:42 PM] training....
# [2023-03-02 11:08:42 PM] training complete
# [2023-03-02 11:08:42 PM] training replay buffer....
# [2023-03-02 11:08:42 PM] training complete
# [2023-03-02 11:08:52 PM] training....
# [2023-03-02 11:08:53 PM] training complete
# [2023-03-02 11:08:54 PM] training....
# [2023-03-02 11:08:54 PM] training complete
# [2023-03-02 11:08:55 PM] training....
# [2023-03-02 11:08:55 PM] training complete
# [2023-03-02 11:08:56 PM] training....
# [2023-03-02 11:08:56 PM] training complete
# [2023-03-02 11:17:46 PM] training....
# [2023-03-02 11:17:46 PM] training complete
# [2023-03-02 11:17:46 PM] training replay buffer....
# [2023-03-02 11:17:46 PM] training complete
# [2023-03-02 11:17:57 PM] training....
# [2023-03-02 11:17:57 PM] training complete
# [2023-03-02 11:17:58 PM] training....
# [2023-03-02 11:17:58 PM] training complete
# [2023-03-02 11:17:59 PM] training....
# [2023-03-02 11:17:59 PM] training complete
# [2023-03-02 11:18:00 PM] training....
# [2023-03-02 11:18:01 PM] training complete
# [2023-03-02 11:26:20 PM] training....
# [2023-03-02 11:26:21 PM] training complete
# [2023-03-02 11:26:21 PM] training replay buffer....
# [2023-03-02 11:26:21 PM] training complete
# [2023-03-02 11:26:31 PM] training....
# [2023-03-02 11:26:32 PM] training complete
# [2023-03-02 11:26:32 PM] training....
# [2023-03-02 11:26:33 PM] training complete
# [2023-03-02 11:26:33 PM] training....
# [2023-03-02 11:26:34 PM] training complete
# [2023-03-02 11:26:35 PM] training....
# [2023-03-02 11:26:35 PM] training complete
# [2023-03-02 11:34:45 PM] training....
# [2023-03-02 11:34:46 PM] training complete
# [2023-03-02 11:34:46 PM] training replay buffer....
# [2023-03-02 11:34:46 PM] training complete
# [2023-03-02 11:34:56 PM] training....
# [2023-03-02 11:34:57 PM] training complete
# [2023-03-02 11:34:57 PM] training....
# [2023-03-02 11:34:58 PM] training complete
# [2023-03-02 11:34:59 PM] training....
# [2023-03-02 11:34:59 PM] training complete
# [2023-03-02 11:35:00 PM] training....
# [2023-03-02 11:35:00 PM] training complete
# [2023-03-02 11:43:34 PM] training....
# [2023-03-02 11:43:35 PM] training complete
# [2023-03-02 11:43:35 PM] training replay buffer....
# [2023-03-02 11:43:35 PM] training complete
# [2023-03-02 11:43:45 PM] training....
# [2023-03-02 11:43:45 PM] training complete
# [2023-03-02 11:43:46 PM] training....
# [2023-03-02 11:43:46 PM] training complete
# [2023-03-02 11:43:47 PM] training....
# [2023-03-02 11:43:48 PM] training complete
# [2023-03-02 11:52:26 PM] training....
# [2023-03-02 11:52:26 PM] training complete
# [2023-03-02 11:52:26 PM] training replay buffer....
# [2023-03-02 11:52:26 PM] training complete
# [2023-03-02 11:52:36 PM] training....
# [2023-03-02 11:52:37 PM] training complete
# [2023-03-02 11:52:38 PM] training....
# [2023-03-02 11:52:38 PM] training complete
# [2023-03-02 11:52:39 PM] training....
# [2023-03-02 11:52:39 PM] training complete
# [2023-03-03 12:00:47 AM] training....
# [2023-03-03 12:00:47 AM] training complete
# [2023-03-03 12:00:47 AM] training replay buffer....
# [2023-03-03 12:00:47 AM] training complete
# [2023-03-03 12:00:58 AM] training....
# [2023-03-03 12:00:58 AM] training complete
# [2023-03-03 12:00:59 AM] training....
# [2023-03-03 12:00:59 AM] training complete
# [2023-03-03 12:01:00 AM] training....
# [2023-03-03 12:01:00 AM] training complete
# [2023-03-03 12:01:01 AM] training....
# [2023-03-03 12:01:02 AM] training complete
# [2023-03-03 12:09:08 AM] training....
# [2023-03-03 12:09:09 AM] training complete
# [2023-03-03 12:09:09 AM] training replay buffer....
# [2023-03-03 12:09:09 AM] training complete
# [2023-03-03 12:09:19 AM] training....
# [2023-03-03 12:09:20 AM] training complete
# [2023-03-03 12:09:21 AM] training....
# [2023-03-03 12:09:21 AM] training complete
# [2023-03-03 12:09:22 AM] training....
# [2023-03-03 12:09:22 AM] training complete
# [2023-03-03 12:09:23 AM] training....
# [2023-03-03 12:09:24 AM] training complete
# [2023-03-03 12:17:50 AM] training....
# [2023-03-03 12:17:50 AM] training complete
# [2023-03-03 12:17:50 AM] training replay buffer....
# [2023-03-03 12:17:50 AM] training complete
# [2023-03-03 12:18:00 AM] training....
# [2023-03-03 12:18:01 AM] training complete
# [2023-03-03 12:18:02 AM] training....
# [2023-03-03 12:18:02 AM] training complete
# [2023-03-03 12:18:03 AM] training....
# [2023-03-03 12:18:03 AM] training complete
# [2023-03-03 12:18:04 AM] training....
# [2023-03-03 12:18:04 AM] training complete
# [2023-03-03 12:27:21 AM] training....
# [2023-03-03 12:27:22 AM] training complete
# [2023-03-03 12:27:22 AM] training replay buffer....
# [2023-03-03 12:27:22 AM] training complete
# [2023-03-03 12:27:32 AM] training....
# [2023-03-03 12:27:32 AM] training complete
# [2023-03-03 12:27:33 AM] training....
# [2023-03-03 12:27:34 AM] training complete
# [2023-03-03 12:27:34 AM] training....
# [2023-03-03 12:27:35 AM] training complete
# [2023-03-03 12:27:35 AM] training....
# [2023-03-03 12:27:36 AM] training complete
# [2023-03-03 12:36:41 AM] training....
# [2023-03-03 12:36:41 AM] training complete
# [2023-03-03 12:36:41 AM] training replay buffer....
# [2023-03-03 12:36:41 AM] training complete
# [2023-03-03 12:36:51 AM] training....
# [2023-03-03 12:36:52 AM] training complete
# [2023-03-03 12:36:52 AM] training....
# [2023-03-03 12:36:53 AM] training complete
# [2023-03-03 12:36:54 AM] training....
# [2023-03-03 12:36:54 AM] training complete
# [2023-03-03 12:36:55 AM] training....
# [2023-03-03 12:36:55 AM] training complete
# [2023-03-03 12:36:56 AM] training....
# [2023-03-03 12:36:56 AM] training complete
# [2023-03-03 12:45:28 AM] training....
# [2023-03-03 12:45:28 AM] training complete
# [2023-03-03 12:45:28 AM] training replay buffer....
# [2023-03-03 12:45:28 AM] training complete
# [2023-03-03 12:45:39 AM] training....
# [2023-03-03 12:45:39 AM] training complete
# [2023-03-03 12:45:40 AM] training....
# [2023-03-03 12:45:40 AM] training complete
# [2023-03-03 12:45:41 AM] training....
# [2023-03-03 12:45:42 AM] training complete
# [2023-03-03 12:45:43 AM] training....
# [2023-03-03 12:45:43 AM] training complete
# [2023-03-03 12:54:06 AM] training....
# [2023-03-03 12:54:06 AM] training complete
# [2023-03-03 12:54:06 AM] training replay buffer....
# [2023-03-03 12:54:06 AM] training complete
# [2023-03-03 12:54:17 AM] training....
# [2023-03-03 12:54:17 AM] training complete
# [2023-03-03 12:54:18 AM] training....
# [2023-03-03 12:54:19 AM] training complete
# [2023-03-03 12:54:19 AM] training....
# [2023-03-03 12:54:20 AM] training complete
# [2023-03-03 12:54:21 AM] training....
# [2023-03-03 12:54:21 AM] training complete
# [2023-03-03 01:02:32 AM] training....
# [2023-03-03 01:02:32 AM] training complete
# [2023-03-03 01:02:32 AM] training replay buffer....
# [2023-03-03 01:02:32 AM] training complete
# [2023-03-03 01:02:42 AM] training....
# [2023-03-03 01:02:43 AM] training complete
# [2023-03-03 01:02:44 AM] training....
# [2023-03-03 01:02:44 AM] training complete
# [2023-03-03 01:02:45 AM] training....
# [2023-03-03 01:02:45 AM] training complete
# [2023-03-03 01:10:56 AM] training....
# [2023-03-03 01:10:57 AM] training complete
# [2023-03-03 01:10:57 AM] training replay buffer....
# [2023-03-03 01:10:57 AM] training complete
# [2023-03-03 01:11:07 AM] training....
# [2023-03-03 01:11:08 AM] training complete
# [2023-03-03 01:11:08 AM] training....
# [2023-03-03 01:11:09 AM] training complete
# [2023-03-03 01:11:10 AM] training....
# [2023-03-03 01:11:10 AM] training complete
# [2023-03-03 01:11:11 AM] training....
# [2023-03-03 01:11:11 AM] training complete
# [2023-03-03 01:19:55 AM] training....
# [2023-03-03 01:19:55 AM] training complete
# [2023-03-03 01:19:55 AM] training replay buffer....
# [2023-03-03 01:19:55 AM] training complete
# [2023-03-03 01:20:05 AM] training....
# [2023-03-03 01:20:06 AM] training complete
# [2023-03-03 01:20:06 AM] training....
# [2023-03-03 01:20:07 AM] training complete
# [2023-03-03 01:20:08 AM] training....
# [2023-03-03 01:20:08 AM] training complete
# [2023-03-03 01:29:12 AM] training....
# [2023-03-03 01:29:12 AM] training complete
# [2023-03-03 01:29:12 AM] training replay buffer....
# [2023-03-03 01:29:12 AM] training complete
# [2023-03-03 01:29:23 AM] training....
# [2023-03-03 01:29:23 AM] training complete
# [2023-03-03 01:29:24 AM] training....
# [2023-03-03 01:29:24 AM] training complete
# [2023-03-03 01:29:25 AM] training....
# [2023-03-03 01:29:26 AM] training complete
# [2023-03-03 01:29:26 AM] training....
# [2023-03-03 01:29:27 AM] training complete
# [2023-03-03 01:38:05 AM] training....
# [2023-03-03 01:38:05 AM] training complete
# [2023-03-03 01:38:05 AM] training replay buffer....
# [2023-03-03 01:38:05 AM] training complete
# [2023-03-03 01:38:16 AM] training....
# [2023-03-03 01:38:16 AM] training complete
# [2023-03-03 01:38:17 AM] training....
# [2023-03-03 01:38:18 AM] training complete
# [2023-03-03 01:38:19 AM] training....
# [2023-03-03 01:38:19 AM] training complete
# [2023-03-03 01:47:04 AM] training....
# [2023-03-03 01:47:04 AM] training complete
# [2023-03-03 01:47:04 AM] training replay buffer....
# [2023-03-03 01:47:04 AM] training complete
# [2023-03-03 01:47:15 AM] training....
# [2023-03-03 01:47:15 AM] training complete
# [2023-03-03 01:47:16 AM] training....
# [2023-03-03 01:47:16 AM] training complete
# [2023-03-03 01:47:17 AM] training....
# [2023-03-03 01:47:17 AM] training complete
# [2023-03-03 01:47:18 AM] training....
# ...
# [2023-03-03 05:48:26 PM] training replay buffer....
# [2023-03-03 05:48:26 PM] training complete
# [2023-03-03 05:48:36 PM] training....
# [2023-03-03 05:48:36 PM] training complete
# [2023-03-03 05:48:37 PM] training....
# [2023-03-03 05:48:37 PM] training complete
# [2023-03-03 05:48:38 PM] training....
# [2023-03-03 05:48:38 PM] training complete
# [2023-03-03 05:48:39 PM] training....
# [2023-03-03 05:48:39 PM] training complete
# [2023-03-03 05:55:21 PM] training....
# [2023-03-03 05:55:21 PM] training complete
# [2023-03-03 05:55:21 PM] training replay buffer....
# [2023-03-03 05:55:21 PM] training complete
# [2023-03-03 05:55:32 PM] training....
# [2023-03-03 05:55:32 PM] training complete
# [2023-03-03 05:55:33 PM] training....
# [2023-03-03 05:55:33 PM] training complete
# [2023-03-03 05:55:34 PM] training....
# [2023-03-03 05:55:34 PM] training complete
# [2023-03-03 05:55:35 PM] training....
# [2023-03-03 05:55:35 PM] training complete
# [2023-03-03 06:02:15 PM] training....
# [2023-03-03 06:02:16 PM] training complete
# [2023-03-03 06:02:16 PM] training replay buffer....
# [2023-03-03 06:02:16 PM] training complete
# [2023-03-03 06:02:26 PM] training....
# [2023-03-03 06:02:27 PM] training complete
# [2023-03-03 06:02:27 PM] training....
# [2023-03-03 06:02:28 PM] training complete
# [2023-03-03 06:02:28 PM] training....
# [2023-03-03 06:02:29 PM] training complete
# [2023-03-03 06:02:29 PM] training....
# [2023-03-03 06:02:30 PM] training complete
# [2023-03-03 06:09:35 PM] training....
# [2023-03-03 06:09:35 PM] training complete
# [2023-03-03 06:09:35 PM] training replay buffer....
# [2023-03-03 06:09:35 PM] training complete
# [2023-03-03 06:09:45 PM] training....
# [2023-03-03 06:09:46 PM] training complete
# [2023-03-03 06:09:46 PM] training....
# [2023-03-03 06:09:47 PM] training complete
# [2023-03-03 06:09:47 PM] training....
# [2023-03-03 06:09:48 PM] training complete
# [2023-03-03 06:09:48 PM] training....
# [2023-03-03 06:09:49 PM] training complete
# [2023-03-03 06:17:06 PM] training....
# [2023-03-03 06:17:06 PM] training complete
# [2023-03-03 06:17:06 PM] training replay buffer....
# [2023-03-03 06:17:06 PM] training complete
# [2023-03-03 06:17:17 PM] training....
# [2023-03-03 06:17:17 PM] training complete
# [2023-03-03 06:17:18 PM] training....
# [2023-03-03 06:17:18 PM] training complete
# [2023-03-03 06:17:19 PM] training....
# [2023-03-03 06:17:19 PM] training complete
# [2023-03-03 06:17:20 PM] training....
# [2023-03-03 06:17:20 PM] training complete
# [2023-03-03 06:24:43 PM] training....
# [2023-03-03 06:24:43 PM] training complete
# [2023-03-03 06:24:43 PM] training replay buffer....
# [2023-03-03 06:24:43 PM] training complete
# [2023-03-03 06:24:53 PM] training....
# [2023-03-03 06:24:54 PM] training complete
# [2023-03-03 06:24:54 PM] training....
# [2023-03-03 06:24:55 PM] training complete
# [2023-03-03 06:24:55 PM] training....
# [2023-03-03 06:24:56 PM] training complete
# [2023-03-03 06:24:56 PM] training....
# [2023-03-03 06:24:57 PM] training complete
# [2023-03-03 06:33:06 PM] training....
# [2023-03-03 06:33:07 PM] training complete
# [2023-03-03 06:33:07 PM] training replay buffer....
# [2023-03-03 06:33:07 PM] training complete
# [2023-03-03 06:33:17 PM] training....
# [2023-03-03 06:33:18 PM] training complete
# [2023-03-03 06:33:18 PM] training....
# [2023-03-03 06:33:19 PM] training complete
# [2023-03-03 06:33:19 PM] training....
# [2023-03-03 06:33:20 PM] training complete
# [2023-03-03 06:33:20 PM] training....
# [2023-03-03 06:33:20 PM] training complete
# [2023-03-03 06:33:21 PM] training....
# [2023-03-03 06:33:21 PM] training complete
# [2023-03-03 06:33:22 PM] training....
# [2023-03-03 06:33:22 PM] training complete
# [2023-03-03 06:41:47 PM] training....
# [2023-03-03 06:41:48 PM] training complete
# [2023-03-03 06:41:48 PM] training replay buffer....
# [2023-03-03 06:41:48 PM] training complete
# [2023-03-03 06:41:58 PM] training....
# [2023-03-03 06:41:58 PM] training complete
# [2023-03-03 06:41:59 PM] training....
# [2023-03-03 06:41:59 PM] training complete
# [2023-03-03 06:42:00 PM] training....
# [2023-03-03 06:42:00 PM] training complete
# [2023-03-03 06:42:01 PM] training....
# [2023-03-03 06:42:01 PM] training complete
# [2023-03-03 06:49:58 PM] training....
# [2023-03-03 06:49:59 PM] training complete
# [2023-03-03 06:49:59 PM] training replay buffer....
# [2023-03-03 06:49:59 PM] training complete
# [2023-03-03 06:50:09 PM] training....
# [2023-03-03 06:50:10 PM] training complete
# [2023-03-03 06:50:10 PM] training....
# [2023-03-03 06:50:11 PM] training complete
# [2023-03-03 06:50:11 PM] training....
# [2023-03-03 06:50:12 PM] training complete
# [2023-03-03 06:50:12 PM] training....
# [2023-03-03 06:50:13 PM] training complete
# [2023-03-03 06:57:51 PM] training....
# [2023-03-03 06:57:51 PM] training complete
# [2023-03-03 06:57:51 PM] training replay buffer....
# [2023-03-03 06:57:51 PM] training complete
# [2023-03-03 06:58:01 PM] training....
# [2023-03-03 06:58:02 PM] training complete
# [2023-03-03 06:58:02 PM] training....
# [2023-03-03 06:58:03 PM] training complete
# [2023-03-03 06:58:03 PM] training....
# [2023-03-03 06:58:04 PM] training complete
# [2023-03-03 06:58:04 PM] training....
# [2023-03-03 06:58:05 PM] training complete
# [2023-03-03 07:06:03 PM] training....
# [2023-03-03 07:06:03 PM] training complete
# [2023-03-03 07:06:03 PM] training replay buffer....
# [2023-03-03 07:06:03 PM] training complete
# [2023-03-03 07:06:13 PM] training....
# [2023-03-03 07:06:14 PM] training complete
# [2023-03-03 07:06:14 PM] training....
# [2023-03-03 07:06:15 PM] training complete
# [2023-03-03 07:06:15 PM] training....
# [2023-03-03 07:06:16 PM] training complete
# [2023-03-03 07:06:16 PM] training....
# [2023-03-03 07:06:17 PM] training complete
# [2023-03-03 07:06:17 PM] training....
# [2023-03-03 07:06:18 PM] training complete
# [2023-03-03 07:06:18 PM] training....
# [2023-03-03 07:06:19 PM] training complete
# [2023-03-03 07:13:57 PM] training....
# [2023-03-03 07:13:58 PM] training complete
# [2023-03-03 07:13:58 PM] training replay buffer....
# [2023-03-03 07:13:58 PM] training complete
# [2023-03-03 07:14:08 PM] training....
# [2023-03-03 07:14:09 PM] training complete
# [2023-03-03 07:14:09 PM] training....
# [2023-03-03 07:14:10 PM] training complete
# [2023-03-03 07:14:10 PM] training....
# [2023-03-03 07:14:11 PM] training complete
# [2023-03-03 07:14:11 PM] training....
# [2023-03-03 07:14:12 PM] training complete
# [2023-03-03 07:14:12 PM] training....
# [2023-03-03 07:14:13 PM] training complete
# [2023-03-03 07:21:30 PM] training....
# [2023-03-03 07:21:30 PM] training complete
# [2023-03-03 07:21:30 PM] training replay buffer....
# [2023-03-03 07:21:30 PM] training complete
# [2023-03-03 07:21:40 PM] training....
# [2023-03-03 07:21:41 PM] training complete
# [2023-03-03 07:21:41 PM] training....
# [2023-03-03 07:21:42 PM] training complete
# [2023-03-03 07:21:42 PM] training....
# [2023-03-03 07:21:43 PM] training complete
# [2023-03-03 07:21:43 PM] training....
# [2023-03-03 07:21:44 PM] training complete
# [2023-03-03 07:21:44 PM] training....
# [2023-03-03 07:21:45 PM] training complete
# [2023-03-03 07:28:28 PM] training....
# [2023-03-03 07:28:28 PM] training complete
# [2023-03-03 07:28:28 PM] training replay buffer....
# [2023-03-03 07:28:28 PM] training complete
# [2023-03-03 07:28:39 PM] training....
# [2023-03-03 07:28:39 PM] training complete
# [2023-03-03 07:28:40 PM] training....
# [2023-03-03 07:28:40 PM] training complete
# [2023-03-03 07:28:41 PM] training....
# [2023-03-03 07:28:41 PM] training complete
# [2023-03-03 07:28:42 PM] training....
# [2023-03-03 07:28:42 PM] training complete
# [2023-03-03 07:35:17 PM] training....
# [2023-03-03 07:35:17 PM] training complete
# [2023-03-03 07:35:17 PM] training replay buffer....
# [2023-03-03 07:35:17 PM] training complete
# [2023-03-03 07:35:28 PM] training....
# [2023-03-03 07:35:28 PM] training complete
# [2023-03-03 07:35:29 PM] training....
# [2023-03-03 07:35:29 PM] training complete
# [2023-03-03 07:35:30 PM] training....
# [2023-03-03 07:35:30 PM] training complete
# [2023-03-03 07:42:15 PM] training....
# [2023-03-03 07:42:15 PM] training complete
# [2023-03-03 07:42:15 PM] training replay buffer....
# [2023-03-03 07:42:15 PM] training complete
# [2023-03-03 07:42:26 PM] training....
# [2023-03-03 07:42:26 PM] training complete
# [2023-03-03 07:42:27 PM] training....
# [2023-03-03 07:42:27 PM] training complete
# [2023-03-03 07:42:28 PM] training....
# [2023-03-03 07:42:28 PM] training complete
# [2023-03-03 07:42:29 PM] training....
# [2023-03-03 07:42:29 PM] training complete
# [2023-03-03 07:49:15 PM] training....
# [2023-03-03 07:49:16 PM] training complete
# [2023-03-03 07:49:16 PM] training replay buffer....
# [2023-03-03 07:49:16 PM] training complete
# [2023-03-03 07:49:26 PM] training....
# [2023-03-03 07:49:26 PM] training complete
# [2023-03-03 07:49:27 PM] training....
# [2023-03-03 07:49:27 PM] training complete
# [2023-03-03 07:49:28 PM] training....
# [2023-03-03 07:49:28 PM] training complete
# [2023-03-03 07:49:29 PM] training....
# [2023-03-03 07:49:29 PM] training complete
# [2023-03-03 07:56:35 PM] training....
# [2023-03-03 07:56:35 PM] training complete
# [2023-03-03 07:56:35 PM] training replay buffer....
# [2023-03-03 07:56:35 PM] training complete
# [2023-03-03 07:56:45 PM] training....
# [2023-03-03 07:56:46 PM] training complete
# [2023-03-03 07:56:46 PM] training....
# [2023-03-03 07:56:47 PM] training complete
# [2023-03-03 07:56:47 PM] training....
# [2023-03-03 07:56:48 PM] training complete
# [2023-03-03 07:56:48 PM] training....
# [2023-03-03 07:56:49 PM] training complete
# [2023-03-03 07:56:49 PM] training....
# [2023-03-03 07:56:50 PM] training complete
# [2023-03-03 08:03:34 PM] training....
# [2023-03-03 08:03:34 PM] training complete
# [2023-03-03 08:03:34 PM] training replay buffer....
# [2023-03-03 08:03:34 PM] training complete
# [2023-03-03 08:03:44 PM] training....
# [2023-03-03 08:03:45 PM] training complete
# [2023-03-03 08:03:45 PM] training....
# [2023-03-03 08:03:46 PM] training complete
# [2023-03-03 08:03:46 PM] training....
# [2023-03-03 08:03:47 PM] training complete
# [2023-03-03 08:03:47 PM] training....
# [2023-03-03 08:03:48 PM] training complete
# [2023-03-03 08:10:19 PM] training....
# [2023-03-03 08:10:20 PM] training complete
# [2023-03-03 08:10:20 PM] training replay buffer....
# [2023-03-03 08:10:20 PM] training complete
# [2023-03-03 08:10:30 PM] training....
# [2023-03-03 08:10:31 PM] training complete
# [2023-03-03 08:10:31 PM] training....
# [2023-03-03 08:10:32 PM] training complete
# [2023-03-03 08:10:32 PM] training....
# [2023-03-03 08:10:33 PM] training complete
# [2023-03-03 08:16:58 PM] training....
# [2023-03-03 08:16:58 PM] training complete
# [2023-03-03 08:16:58 PM] training replay buffer....
# [2023-03-03 08:16:58 PM] training complete
# [2023-03-03 08:17:08 PM] training....
# [2023-03-03 08:17:09 PM] training complete
# [2023-03-03 08:17:09 PM] training....
# [2023-03-03 08:17:10 PM] training complete
# [2023-03-03 08:17:10 PM] training....
# [2023-03-03 08:17:11 PM] training complete
# [2023-03-03 08:17:11 PM] training....
# [2023-03-03 08:17:12 PM] training complete
# [2023-03-03 08:24:06 PM] training....
# [2023-03-03 08:24:07 PM] training complete
# [2023-03-03 08:24:07 PM] training replay buffer....
# [2023-03-03 08:24:07 PM] training complete
# [2023-03-03 08:24:17 PM] training....
# [2023-03-03 08:24:18 PM] training complete
# [2023-03-03 08:24:18 PM] training....
# [2023-03-03 08:24:19 PM] training complete
# [2023-03-03 08:24:19 PM] training....
# [2023-03-03 08:24:20 PM] training complete
# [2023-03-03 08:24:20 PM] training....
# [2023-03-03 08:24:21 PM] training complete
# [2023-03-03 08:31:20 PM] training....
# [2023-03-03 08:31:20 PM] training complete
# [2023-03-03 08:31:20 PM] training replay buffer....
# [2023-03-03 08:31:20 PM] training complete
# [2023-03-03 08:31:30 PM] training....
# [2023-03-03 08:31:31 PM] training complete
# [2023-03-03 08:31:31 PM] training....
# [2023-03-03 08:31:32 PM] training complete
# [2023-03-03 08:31:32 PM] training....
# [2023-03-03 08:31:32 PM] training complete
# [2023-03-03 08:31:33 PM] training....
# [2023-03-03 08:31:33 PM] training complete
# [2023-03-03 08:31:34 PM] training....
# [2023-03-03 08:31:34 PM] training complete
# [2023-03-03 08:38:37 PM] training....
# [2023-03-03 08:38:37 PM] training complete
# [2023-03-03 08:38:37 PM] training replay buffer....
# [2023-03-03 08:38:37 PM] training complete
# [2023-03-03 08:38:47 PM] training....
# [2023-03-03 08:38:48 PM] training complete
# [2023-03-03 08:38:48 PM] training....
# [2023-03-03 08:38:49 PM] training complete
# [2023-03-03 08:38:49 PM] training....
# [2023-03-03 08:38:50 PM] training complete
# [2023-03-03 08:38:50 PM] training....
# [2023-03-03 08:38:51 PM] training complete
# [2023-03-03 08:46:00 PM] training....
# [2023-03-03 08:46:00 PM] training complete
# [2023-03-03 08:46:00 PM] training replay buffer....
# [2023-03-03 08:46:00 PM] training complete
# [2023-03-03 08:46:11 PM] training....
# [2023-03-03 08:46:11 PM] training complete
# [2023-03-03 08:46:12 PM] training....
# [2023-03-03 08:46:12 PM] training complete
# [2023-03-03 08:46:13 PM] training....
# [2023-03-03 08:46:13 PM] training complete
# [2023-03-03 08:46:14 PM] training....
# [2023-03-03 08:46:14 PM] training complete
# [2023-03-03 08:46:15 PM] training....
# [2023-03-03 08:46:15 PM] training complete
# [2023-03-03 08:53:16 PM] training....
# [2023-03-03 08:53:17 PM] training complete
# [2023-03-03 08:53:17 PM] training replay buffer....
# [2023-03-03 08:53:17 PM] training complete
# [2023-03-03 08:53:27 PM] training....
# [2023-03-03 08:53:28 PM] training complete
# [2023-03-03 08:53:28 PM] training....
# [2023-03-03 08:53:28 PM] training complete
# [2023-03-03 08:53:29 PM] training....
# [2023-03-03 08:53:29 PM] training complete
# [2023-03-03 08:53:30 PM] training....
# [2023-03-03 08:53:30 PM] training complete
# [2023-03-03 09:00:33 PM] training....
# [2023-03-03 09:00:33 PM] training complete
# [2023-03-03 09:00:33 PM] training replay buffer....
# [2023-03-03 09:00:33 PM] training complete
# [2023-03-03 09:00:43 PM] training....
# [2023-03-03 09:00:44 PM] training complete
# [2023-03-03 09:00:44 PM] training....
# [2023-03-03 09:00:45 PM] training complete
# [2023-03-03 09:00:45 PM] training....
# [2023-03-03 09:00:46 PM] training complete
# [2023-03-03 09:00:46 PM] training....
# [2023-03-03 09:00:47 PM] training complete
# [2023-03-03 09:00:47 PM] training....
# [2023-03-03 09:00:48 PM] training complete
# [2023-03-03 09:08:46 PM] training....
# [2023-03-03 09:08:46 PM] training complete
# [2023-03-03 09:08:46 PM] training replay buffer....
# [2023-03-03 09:08:46 PM] training complete
# [2023-03-03 09:08:56 PM] training....
# [2023-03-03 09:08:57 PM] training complete
# [2023-03-03 09:08:58 PM] training....
# [2023-03-03 09:08:58 PM] training complete
# [2023-03-03 09:08:58 PM] training....
# [2023-03-03 09:08:59 PM] training complete
# [2023-03-03 09:08:59 PM] training....
# [2023-03-03 09:09:00 PM] training complete
# [2023-03-03 09:09:00 PM] training....
# [2023-03-03 09:09:01 PM] training complete
# [2023-03-03 09:09:01 PM] training....
# [2023-03-03 09:09:02 PM] training complete
# [2023-03-03 09:16:28 PM] training....
# [2023-03-03 09:16:29 PM] training complete
# [2023-03-03 09:16:29 PM] training replay buffer....
# [2023-03-03 09:16:29 PM] training complete
# [2023-03-03 09:16:39 PM] training....
# [2023-03-03 09:16:40 PM] training complete
# [2023-03-03 09:16:40 PM] training....
# [2023-03-03 09:16:40 PM] training complete
# [2023-03-03 09:16:41 PM] training....
# [2023-03-03 09:16:41 PM] training complete
# [2023-03-03 09:16:42 PM] training....
# [2023-03-03 09:16:42 PM] training complete
# [2023-03-03 09:16:43 PM] training....
# [2023-03-03 09:16:43 PM] training complete
# [2023-03-03 09:23:57 PM] training....
# [2023-03-03 09:23:57 PM] training complete
# [2023-03-03 09:23:57 PM] training replay buffer....
# [2023-03-03 09:23:57 PM] training complete
# [2023-03-03 09:24:07 PM] training....
# [2023-03-03 09:24:07 PM] training complete
# [2023-03-03 09:24:08 PM] training....
# [2023-03-03 09:24:08 PM] training complete
# [2023-03-03 09:24:09 PM] training....
# [2023-03-03 09:24:09 PM] training complete
# [2023-03-03 09:24:10 PM] training....
# [2023-03-03 09:24:10 PM] training complete
# [2023-03-03 09:24:11 PM] training....
# [2023-03-03 09:24:11 PM] training complete
# [2023-03-03 09:24:12 PM] training....
# [2023-03-03 09:24:12 PM] training complete

# %%
from torch.profiler import profile, record_function, ProfilerActivity

with profile(activities=[ProfilerActivity.CPU], record_shapes=True) as prof:
        with record_function("model_inference"):
            for i in range(10):
                print(i)
            
print(prof.key_averages().table(sort_by="cpu_time_total", row_limit=10))

# %%
a = torch.randn(2, 5)
print(a)

a = a.unsqueeze(1)
print(a.shape)
print(a)

a = a.repeat(1, 4, 1)
print(a.shape)
print(a)
