# %%
import numpy as np

# %%
jitter_wspt = [110.422, 113.372, 116.011, 116.585, 119.697, 125.07, 128.689, 131.396, 132.246, 135.358, 140.011, 143.697, 146.422, 146.506, 149.372, 155.396, 159.358, 161.07, 161.577, 170.422, 173.26, 173.372, 176.011, 176.585, 179.697, 185.07, 188.689, 191.396, 192.246, 195.358]
jitter_make_wspt = [1.0, 1.0, 2.0, 3.0, 3.0, 4.0, 4.0, 8.0, 8.0, 9.0, 10.0, 11.0, 11.0, 12.0, 12.0, 13.0, 14.0, 14.0, 15.0, 15.0, 15.0, 16.0, 16.0, 17.0, 17.0, 17.0, 18.0, 19.0, 23.0, 24.0, 25.0, 27.0, 27.0, 28.0, 29.0, 29.0, 30.0, 32.0, 33.0, 35.0, 35.0, 37.0, 39.0, 39.0, 39.0, 43.0, 44.0, 45.0, 45.0, 47.0, 49.0, 50.0, 50.0, 51.0, 51.0, 52.0, 53.0, 54.0, 54.0, 56.0, 56.0, 58.0, 58.0, 59.0, 60.0, 60.0, 60.0, 60.0, 61.0, 61.0, 61.0, 62.0, 63.0, 63.0, 64.0, 64.0, 64.0, 65.0, 65.0, 66.0, 67.0, 69.0, 69.0, 70.0, 70.0, 71.0, 72.0, 73.0, 74.0, 76.0, 78.0, 78.0, 79.0, 79.0, 79.0, 82.0, 83.0, 83.0, 84.0, 86.0, 87.0, 88.0, 88.0, 88.0, 90.0, 91.0, 91.0, 92.0, 93.0, 94.0, 96.0, 97.0, 98.0, 98.0]

# %%
jitter_wspt = np.diff(np.array(jitter_wspt))
jitter_make_wspt = np.diff(np.array(jitter_make_wspt))

# %%
for i in jitter_wspt:
    print(i)

for i in range(100):
    print("")
# Out:
# 2.950000000000003
# 2.638999999999996
# 0.5739999999999981
# 3.112000000000009
# 5.3729999999999905
# 3.6189999999999998
# 2.7069999999999936
# 0.8500000000000227
# 3.1119999999999948
# 4.652999999999992
# 3.686000000000007
# 2.7249999999999943
# 0.08400000000000318
# 2.866000000000014
# 6.0239999999999725
# 3.9620000000000175
# 1.711999999999989
# 0.507000000000005
# 8.844999999999999
# 2.837999999999994
# 0.11200000000002319
# 2.6389999999999816
# 0.5740000000000123
# 3.1119999999999948
# 5.3729999999999905
# 3.6189999999999998
# 2.7069999999999936
# 0.8500000000000227
# 3.1119999999999948

# %%
for i in jitter_make_wspt:
    print(i)

# %%
a = [3.77667, 5.84, 7.90333, 8.39, 8.47667, 10.5233, 11.02, 11.09, 11.5767, 14.5767, 14.5767, 15.39, 15.7033, 17.4467, 17.7767, 18.1767, 20.0833, 20.24, 20.24, 21.02, 22.39, 23.25, 24.4533, 25.3833, 26.2767, 28.5833, 29.2767, 30.24, 30.24, 30.31, 31.3767, 32.2767, 32.8767, 35.1833, 35.4267, 35.4967, 36.4833, 38.0767, 38.1767, 38.1767, 38.6767, 40.14, 41.82, 43.8833, 45.5767, 46.7767, 46.7767, 48.1967, 48.91, 50.9733, 53.28, 53.28, 53.28, 55.3433, 55.4133, 57.72, 57.79, 57.9633, 59.9567, 60.0267, 62.5767, 66.46, 66.46, 66.53, 68.6633, 68.6633, 71.04, 71.04, 71.2833, 71.8567, 73.6767, 73.6767, 73.92, 75.41, 76.4767, 77.02, 77.4733, 77.6133, 79.0833, 79.6767, 80.2767, 81.9833, 82.41, 82.41, 82.4767, 84.7867, 85.4767, 87.14, 87.3833, 89.6733, 89.6733, 89.7767, 89.8467, 92.4767, 92.5767, 93.8867, 94.64, 94.64, 96.4767, 97.0167, 97.4767, 97.4767, 98.2133]
a = np.array(a)
b = np.diff(a)

# %%
print(b.std())
print(b.mean())

# %%
a = [1.0, 1.0, 2.0, 3.0, 3.0, 4.0, 4.0, 8.0, 8.0, 9.0, 10.0, 11.0, 11.0, 12.0, 12.0, 13.0, 14.0, 14.0, 15.0, 15.0, 15.0, 16.0, 16.0, 17.0, 17.0, 17.0, 18.0, 19.0, 23.0, 24.0, 25.0, 27.0, 27.0, 28.0, 29.0, 29.0, 30.0, 32.0, 33.0, 35.0, 35.0, 37.0, 39.0, 39.0, 39.0, 43.0, 44.0, 45.0, 45.0, 47.0, 49.0, 50.0, 50.0, 51.0, 51.0, 52.0, 53.0, 54.0, 54.0, 56.0, 56.0, 58.0, 58.0, 59.0, 60.0, 60.0, 60.0, 60.0, 61.0, 61.0, 61.0, 62.0, 63.0, 63.0, 64.0, 64.0, 64.0, 65.0, 65.0, 66.0, 67.0, 69.0, 69.0, 70.0, 70.0, 71.0, 72.0, 73.0, 74.0, 76.0, 78.0, 78.0, 79.0, 79.0, 79.0, 82.0, 83.0, 83.0, 84.0, 86.0, 87.0, 88.0, 88.0, 88.0, 90.0, 91.0, 91.0, 92.0, 93.0, 94.0, 96.0, 97.0, 98.0, 98.0]
a = np.array(a)
b = np.diff(a)

# %%
print(b.std())
print(b.mean())

# %%
for i in b:
    print(i)
